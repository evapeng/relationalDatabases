# %%
import csv
import sqlite3
import pandas as pd
import math
# Use svg backend for better quality
import matplotlib
# AUTOLAB_IGNORE_START
matplotlib.use("svg")
# AUTOLAB_IGNORE_STOP
import matplotlib.pyplot as plt
# AUTOLAB_IGNORE_START
# %matplotlib inline
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (10.0, 5.0) # you should adjust this to fit your screen
# AUTOLAB_IGNORE_STOP

# %% [markdown]
# # Relational Data and Visualization [30pts]
# In this problem, you will be analyzing the Twitter data we extracted using [this](https://dev.twitter.com/overview/api) api. The data consists of Twitter users (with unique handles) and their attributes (e.g., number of followers), some recent tweets posted by them with attributes (e.g., time stamp, number of retweets), and the follow relationship between the users. These are available in the three CSV files provided to you:
# - users.csv - users, user attributes
# - edges.csv - follow edges (directed, an edge from A to B means A follows B or B is a friend of A)
# - tweets.csv - tweets posted by the users along with its attributes

# %% [markdown]
# ## Q1. Relational Data [5pts + 6pts + 6pts]
# This question will guide you through loading Twitter data into an in-memory SQLite database and running some basic queries on it.

# %% [markdown]
# ### Q1. Task A: Load Twitter data into SQLite database [5pts]
# Your first task is to use the csv and sqlite3 python packages to load the three csv files we give you as relations (or tables) into an SQLite in-memory database.
#
# Loading the data from csv file into the database involves the following steps:
# 1. Identify the schema of the table (for this problem, you will only need TEXT and INTEGER attribute types)
# 2. Create a table with the identified schema
# 3. Load the contents of csv in memory
# 4. Insert every row of csv file as a record in the table
#
# You can refer to [sqlite3 documentation](https://docs.python.org/2/library/sqlite3.html) and the class lecture for steps 2 and 4. For step 3, refer to the [csv documentation](https://docs.python.org/2/library/csv.html). Be sure to name your tables `users`, `edges`, and `tweets`.
#
# Make sure to commit (the equivalent of Ctrl+S for databases) any changes you make to the database. [This](https://www.techopedia.com/definition/16/commit) page should give you an idea about why commit is essential.

# %% [markdown]
# Your function will be called as in the cell below. The cell also contains some test code to display all tables in the database. You may want to write you own tests for the individual tables to verify that the data has been loaded properly. (e.g., number of tuples in each table)

# %%
def load_twitter_data_sqlite3(conn, users_filepath, edges_filepath, tweets_filepath) :
    """ Load twitter data in the three files as tables into an in-memory SQLite database
    Input:
        conn (sqlite3.Connection) : Connection object corresponding to the database; used to perform SQL commands.
        users_filepath (str) : absolute/relative path to users.csv file
        edges_filepath (str) : absolute/relative path to edges.csv file
        tweets_filepath (str) : absolute/relative path to tweets.csv file
    Output:
        None
    """
    
    cursor = conn.cursor()
    
    cursor.execute("""
    CREATE TABLE tweets (
        screen_name TEXT,
        created_at TEXT,
        retweet_count INTEGER,
        favorite_count INTEGER,
        text TEXT)
    """)
    
    cursor.execute("""
    CREATE TABLE users (
        name TEXT,
        screen_name TEXT PRIMARY KEY,
        location TEXT,
        created_at TEXT,
        friends_count INTEGER,
        followers_count INTEGER,
        statuses_count INTEGER,
        favourites_count INTEGER)
    """)
        
    cursor.execute("""
    CREATE TABLE edges (
        screen_name TEXT,
        friend TEXT)
    """)
    
    with open(tweets_filepath,'rb') as csvfile:
        dr = csv.DictReader(csvfile)
        to_db = [(i['screen_name'],i['created_at'],i['retweet_count'],i['favorite_count'],i['text']) for i in dr]
        
    conn.executemany("INSERT INTO tweets (screen_name,created_at,retweet_count,favorite_count,text) VALUES (?,?,?,?,?);", to_db)
    
    with open(users_filepath,'rb') as csvfile:
        dr = csv.DictReader(csvfile)
        to_db = [(i['name'],i['screen_name'],i['location'],
                  i['created_at'],i['friends_count'],i['followers_count'],
                  i['statuses_count'],i['favourites_count']) for i in dr]
            
    conn.executemany("INSERT INTO users (name,screen_name,location,created_at,friends_count,followers_count,statuses_count,favourites_count) VALUES (?,?,?,?,?,?,?,?);", to_db)
    
    with open(edges_filepath,'rb') as csvfile:
        dr = csv.DictReader(csvfile)
        to_db = [(i['screen_name'],i['friend']) for i in dr]
            
    conn.executemany("INSERT INTO edges (screen_name,friend) VALUES (?,?);", to_db)
    
    conn.commit()

# %%
# AUTOLAB_IGNORE_START
# connect to an in memory database
conn = sqlite3.connect(":memory:")
conn.text_factory = str
# call to your function
load_twitter_data_sqlite3(conn, 'users.csv', 'edges.csv', 'tweets.csv')
# make sure to change the path to csv files appropriately
cursor = conn.cursor()
# prints all tables in the database
for row in cursor.execute("SELECT name FROM sqlite_master WHERE type = 'table';"):
    print row
# for row in cursor.execute("SELECT * FROM users;"):
#     print row 
# AUTOLAB_IGNORE_STOP
# Out:
# ('tweets',)
# ('users',)
# ('edges',)

# %% [markdown]
# ### Q1. Task B: Trending tweets in a topic [6pts]
# Twitter is regarded as an invaluable source of valuable information. Hence, one of the favorite tasks of data miners is the analyse the trending tweets in a given topic.
#
# This task requires you to retrieve the top N most trending tweets (in descending order of trending_score) about a given topic (which is a list of keywords). The following information may be useful:
#
# - A tweet is said to be about a given topic if it contains any of the given topical phrases/keywords.
# - We will use the following simple trending_score: retweet_count + favorite_count. Tweets with higher trending_score must be ranked before the ones with lower trending_score.
# - Your result must contain unique tweets. If a tweet text occurs multiple times, display it only once with its highest trending_score.
# - Break ties by sorting the tweets in alphabetical order.
#
# The output schema should be as follows:
#
# |tweet (TEXT)| trending_score (INTEGER) |
# | :--- |:--- |
# | | |

# %%
def trending_tweets(cursor, topical_phrases=['Hillary', 'Clinton'], N=5):
    """ Retrieves the top N trending tweets containing one or more of the given topical phrases.
    Input:
        cursor (sqlite3.Cursor): Cursor object to query the database.
        topical_phrases (list of strings): A list of keywords identifying a topic.
        N: Number of trending tweets to retrieve
    Output:
        results (sqlite3.Cursor): Cursor object which can be used to iterate over the retrieved records/tuples.
    """
    whereClause = ""
    i = 0
    for word in topical_phrases:
        if i == 0:
            whereClause = " text LIKE '%" + word+ "%'"
        else:
            whereClause += " OR text LIKE '%" + word + "%'"
        i += 1
        
    query = "SELECT text AS tweet, retweet_count + favorite_count AS trending_score FROM tweets WHERE {0} GROUP BY text ORDER BY retweet_count + favorite_count DESC, text LIMIT {1}".format(whereClause,N) # your query here
    
    results = cursor.execute(query)
    return results

# %% [markdown]
# The default inputs to the function will retrieve 5 trending tweets about topic Hillary Clinton. You can view the output of your query using the following code.

# %%
# AUTOLAB_IGNORE_START
results = trending_tweets(conn.cursor())
# for row in results:
#     print row
# AUTOLAB_IGNORE_STOP
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-25-e41659160ae9> in <module>()
#       3 # for row in results:
#       4 #     print row
# ----> 5 for row in cursor.execute("SELECT name FROM results WHERE type = 'table';"):
#       6     print row
#       7 # AUTOLAB_IGNORE_STOP
#
# OperationalError: no such table: results

# %% [markdown]
# ### Q1. Task C: Tweet recommendation [6pts]
# How does Twitter go about populating the feed for a user? While Twitter may use a comple models to do this, in this task, we will use a Simple Tweet Recommender (STR), which recommends a user's tweets to all users who follow him/her (without checking for possible duplicates; i.e., STR may recommend the same tweet twice if two of a user's friends have posted it).
#
# In this task, you will write a query to determine the number of tweets recommended to each user. Use only the snapshot of edges and tweets we have provided to you to do the recommendation. Report the results on the users present in the users table. (Hint: The number of records in your output should match that in the "users" table.) The order of results does not matter.
#
# The output schema should be:
#
# |screen_name (TEXT)| num_tweets (INTEGER) |
# | :--- |:--- |
# | | | |

# %%
def num_tweets_in_feed(cursor):
    """ Retrieves the number of tweets STR recommends to each Twitter user.
    Input:
        cursor (sqlite3.Cursor): Cursor object to query the database.
    Output:
        results (sqlite3.Cursor): Cursor object which can be used to iterate over the retrieved records/tuples.
    """
    #for each user we add up all the tweets from the edges going out of that user 
    #group by screen_name (users.screename) 
    
    #match each friend with all tweets made by that person 
    #edges.friend LEFT JOIN tweets.screen_name GROUP BY screen_name
    query = """
    SELECT users.screen_name AS screen_name, ifnull(INN.num_tweets,0) as num_tweets 
    FROM users LEFT OUTER JOIN 
        (SELECT edges.screen_name, COUNT(tweets.text) AS num_tweets
        FROM edges LEFT OUTER JOIN tweets ON edges.friend = tweets.screen_name 
        GROUP BY edges.screen_name) INN ON users.screen_name = INN.screen_name
    """
    return cursor.execute(query)

# AUTOLAB_IGNORE_START
# results = num_tweets_in_feed(conn.cursor())
# count = 0
# for row in results:
#     count +=1
#     print row
# print count

i = 0
# for row in results:
#     if row[1]==0:
#       print row
#     if i>20:
#         break
#     i += 1
# AUTOLAB_IGNORE_STOP
# Out:
# ('0', 0)
# ('04spence', 0)
# ('09BRAININJURY', 0)
# ('0lympiaB', 0)
# ('100holehike', 0)
# ('10AJMcCarron', 0)
# ('10BestDesign', 0)
# ('1200WOAI', 0)
# ('120Sports', 0)
# ('13KCliffy', 0)
# ('13MeganM', 0)
# ('15thClub', 0)
# ('1800aajewelry', 0)
# ('1975matea', 0)
# ('19Weather', 0)
# ('19jamie22Brown', 0)
# ('1DegreeMgmt', 0)
# ('1Eppy1', 0)
# ('1Hotels', 0)
# ('1NtheREALM', 0)
# ('1Rowland1', 0)
# ('1StrongMother', 0)
# ('1Tosh_Fan', 0)
# ('1af178398a524e7', 0)
# ('1avalongirl', 0)
# ('1carpediem2016', 0)
# ('1ceniyi', 0)
# ('1iota', 0)
# ('1jameshuang', 0)
# ('1lolamarina', 0)
# ('1soyeonryu', 0)
# ('2011womensopen', 0)
# ('2016CLE', 0)
# ('2016MikeWebbVA8', 0)
# ('2016OlympicGolf', 0)
# ('2016WCC', 0)
# ('2016woig', 0)
# ('21CF', 0)
# ('247Sports', 0)
# ('2Kennedysisters', 0)
# ('2TylerBrown', 0)
# ('2UNDR', 0)
# ('30for30', 0)
# ('360yourlife', 0)
# ('3MChampionship', 0)
# ('3creekranchgolf', 0)
# ('44_Matakevich', 0)
# ('45ParkLaneUK', 0)
# ('4900c2bed749486', 0)
# ('4Luxury_Travel', 0)
# ('4MWM4', 0)
# ('4golfonline', 0)
# ('4kingandcountry', 0)
# ('4sportsworld', 0)
# ('50MClub', 0)
# ('50cent', 0)
# ('54Below', 0)
# ('5DollarTravel', 0)
# ('5JAYKIDS', 0)
# ('5MilesPastEmpty', 0)
# ('5secsofzixll', 0)
# ('60Minutes', 0)
# ('702_mag', 0)
# ('70s_party', 0)
# ('78_RS', 0)
# ('808IkeRoyal', 0)
# ('80Breakr', 0)
# ('837NYC', 0)
# ('923WCOL', 0)
# ('925XTU', 0)
# ('949WQMX', 0)
# ('949starcountry', 0)
# ('95MilestoGo', 0)
# ('969thekat', 0)
# ('96Elephants', 0)
# ('9KidFitness', 0)
# ('9modano', 0)
# ('AAA_Travel', 0)
# ('AAC_Golf', 0)
# ('AAHSAWARD', 0)
# ('AAJorgensen', 0)
# ('AAMScottishOpen', 0)
# ('AASquaredBlog', 0)
# ('AArroyoPodium', 0)
# ('ABC', 0)
# ('ABC7NY', 0)
# ('ABCCocina', 0)
# ('ABCLiz', 0)
# ('ABCPolitics', 0)
# ('ABCSharkTank', 0)
# ('ABCWorldNews', 0)
# ('ABNorthFoodBank', 0)
# ('ABSoberg', 0)
# ('ABZ_Airport', 0)
# ('AC360', 60)
# ('ACChampionship', 0)
# ('ACMLondon', 0)
# ('ACTIONNOWAK', 0)
# ('ACsports', 0)
# ('ADAMDEVINE', 0)
# ('ADCuthbertson', 0)
# ('ADGolfClub', 0)
# ('ADP', 0)
# ('ADPCareers', 0)
# ('AD_Oficial', 0)
# ('ADaroczy', 0)
# ('ADavidson43', 0)
# ('ADtheseries', 0)
# ('AECC_Aberdeen', 0)
# ('AECC_Steven', 0)
# ('AFandango', 0)
# ('AFloresBeauty', 0)
# ('AFootintheRough', 0)
# ('AGLotz', 0)
# ('AGRutledge', 0)
# ('AGlewen', 0)
# ('AIR_Ford', 0)
# ('AJBrooks', 0)
# ('AJDelgado13', 0)
# ('AJENews', 0)
# ('AJEnglish', 0)
# ('AJGAGolf', 0)
# ('AJGAMedia', 0)
# ('AKson85', 0)
# ('ALBAlegacy', 0)
# ('ALBERTOeGOMEZ', 0)
# ('ALEXSHERA', 0)
# ('ALaForce', 0)
# ('ALevyNYC', 0)
# ('AM3RICANCentaur', 0)
# ('AMSRadioShow', 0)
# ('AMurrayGolf', 0)
# ('ANAinspiration', 0)
# ('ANHQDC', 0)
# ('ANNCAIN_', 0)
# ('ANNIKA59', 0)
# ('ANordqvist', 0)
# ('AOL', 0)
# ('AOLLifestyle', 0)
# ('AP', 0)
# ('APAWhatsOn', 0)
# ('APAlliance', 0)
# ('APBayHill', 0)
# ('APBusiness', 0)
# ('APCentralRegion', 0)
# ('APDCgolf', 0)
# ('APEastRegion', 0)
# ('APEntertainment', 0)
# ('APSouthRegion', 0)
# ('APWestRegion', 0)
# ('AP_Archive', 0)
# ('AP_Boston', 0)
# ('AP_FDAwriter', 0)
# ('AP_Fashion', 0)
# ('AP_Jobs', 0)
# ('AP_NFL', 0)
# ('AP_Oddities', 0)
# ('AP_Sports', 0)
# ('AP_Tokyo', 0)
# ('AP_VideoAlert', 0)
# ('AP_VideoHub', 0)
# ('APassportAffair', 0)
# ('APinv', 0)
# ('APjoshgoodman', 0)
# ('APklug', 0)
# ('ARRohr', 0)
# ('ARizzo44', 0)
# ('ARoberts1983', 0)
# ('ARy32', 0)
# ('ASBMT', 0)
# ('ASDFitnessCtr', 0)
# ('ASICSeurope', 0)
# ('ASavageNation', 0)
# ('AShamaris', 0)
# ('AShulman2', 0)
# ('ASiegalEisman', 0)
# ('ASpauldingNJH', 0)
# ('ASteiner', 0)
# ('ATLHawks', 0)
# ('ATT', 0)
# ('AUG_Masters', 0)
# ('AUSOlympicTeam', 0)
# ('AVCAVolleyball', 0)
# ('AVENUEinsider', 0)
# ('AVelagi', 0)
# ('AWilliamson54', 0)
# ('A_Heard21', 0)
# ('A_Sciarretta13', 0)
# ('AaronBack', 0)
# ('AaronBadds', 0)
# ('AaronBondaroff', 0)
# ('AaronMcAllorum', 0)
# ('AaronOhloff', 0)
# ('AaronPetersRN', 0)
# ('AaronRodgers12', 0)
# ('AaronTaylorCFB', 0)
# ('AbbeyTours', 0)
# ('AbbyWambach', 0)
# ('AbdnInspired', 0)
# ('Abe_Froeman', 0)
# ('Abelinetexas', 0)
# ('AberdeenCC', 0)
# ('AberdeenCity', 0)
# ('AbhishekSruia', 0)
# ('AbigailDJ', 0)
# ('AbigailKirsch', 0)
# ('AboveAverage', 0)
# ('Abs_NBC', 0)
# ('Abyss84Jigsaw', 0)
# ('AceHardware', 0)
# ('AceSpecialties', 0)
# ('AchieveInsights', 0)
# ('AchievementBird', 0)
# ('Acosta', 0)
# ('ActuallyNPH', 0)
# ('AdBell45', 0)
# ('AdamGrabert', 0)
# ('AdamJohnsonNJ', 0)
# ('AdamLefkoe', 0)
# ('AdamLipson', 0)
# ('AdamRPatrick', 0)
# ('AdamRentonWard', 0)
# ('AdamRubinESPN', 0)
# ('AdamSample', 0)
# ('AdamSandler', 0)
# ('AdamSchefter', 0)
# ('AdamSchein', 0)
# ('AdamSchindler', 0)
# ('AdamShawNY', 0)
# ('AdamStewart', 0)
# ('AdamTillery', 0)
# ('AdamZHerman', 0)
# ('Adam_K_Levin', 0)
# ('Adam_Levy', 0)
# ('Adam_Sarson', 0)
# ('AdamsGolf', 0)
# ('Addictd2Success', 0)
# ('AddictionNVL', 0)
# ('AdityoBlc', 0)
# ('AdornInsight', 0)
# ('Adornmentality', 0)
# ('AdrenalineFilm1', 0)
# ('Adrian__Pantoja', 0)
# ('AdrianaCohen16', 0)
# ('AdrianneHaslet', 0)
# ('Adriansimmonds1', 0)
# ('AdrienneVogt', 0)
# ('Adweek', 0)
# ('AerLingus', 0)
# ('AfraBint', 0)
# ('AfterSexWords', 0)
# ('AgCorbett123', 0)
# ('Aghadoe_Heights', 0)
# ('Ahlex3889', 0)
# ('AhnaHendrix', 0)
# ('AhooksHooks', 0)
# ('AimPointGolf', 0)
# ('AimpointUSA', 0)
# ('AinePurcell', 0)
# ('AirForceWife475', 0)
# ('AirFreed', 0)
# ('AirbusLPGA', 0)
# ('AirlieWalsh', 0)
# ('AirportACK', 0)
# ('Airstream4Sale', 0)
# ('AkronRacers', 0)
# ('AkronsVO_21', 0)
# ('AlConklin', 0)
# ('AlEiSHA_grace', 0)
# ('AlUCanEatShrimp', 0)
# ('AlZorahGolfClub', 0)
# ('Al_B_Damned', 0)
# ('Al_Baldasaro', 0)
# ('Al_Demmer', 0)
# ('Al_Drago', 0)
# ('Al_Leiter22', 0)
# ('AlabamaFTBL', 0)
# ('AlaminYohannes', 0)
# ('AlanColmes', 0)
# ('AlanJeffery10', 0)
# ('AlanPittmanGD', 0)
# ('AlanShipnuck', 0)
# ('AlanWarrickII', 0)
# ('AlanaSwainGolf', 0)
# ('Alastair_McLeod', 0)
# ('AlbatrossGlobal', 0)
# ('AlbemarleEstate', 0)
# ('AlbertBreer', 0)
# ('AlbertoPants', 0)
# ('AlbieManzo', 0)
# ('AlecGolini', 0)
# ('Aleksander_Lee', 0)
# ('AlenaShishkova', 0)
# ('Aleventuras', 0)
# ('AlexCsi', 0)
# ('AlexGParsons', 0)
# ('AlexHenderson17', 0)
# ('AlexHoggy247', 0)
# ('AlexJamesFitz', 0)
# ('AlexLato', 0)
# ('AlexMyers3', 0)
# ('AlexRochagolf', 0)
# ('AlexSkatell', 0)
# ('AlexSteinman', 0)
# ('AlexWhiteEdits', 0)
# ('Alex_Noren', 0)
# ('Alex_Rusaw', 0)
# ('Alex__Tolbert', 0)
# ('Alexa_Belle_', 0)
# ('Alextheproducer', 0)
# ('Alfred_James', 0)
# ('Alhi873', 0)
# ('AliBradleyTV', 0)
# ('AliFedotowsky', 0)
# ('AliKickLPGA', 0)
# ('AliNolan7', 0)
# ('AlianaGalan', 0)
# ('AliceNaberLozem', 0)
# ('AliciaHMalnati', 0)
# ('AljazSkorjanec', 0)
# ('AllBrighterDays', 0)
# ('AllStarGolfCamp', 0)
# ('Allan70178043', 0)
# ('AllanMintoGolf', 0)
# ('Alldaybustos', 0)
# ('Allegdeuce', 0)
# ('Allergan', 0)
# ('AlliemalCNN', 0)
# ('AllisonBJanney', 0)
# ('Allure_magazine', 0)
# ('AllynCutts', 0)
# ('Almighty_manny', 0)
# ('AloysiusIV', 0)
# ('Alsboringtweets', 0)
# ('AltRights', 0)
# ('AltonLane', 0)
# ('AlvedaCKing', 0)
# ('Always', 0)
# ('AlwaysHungryChi', 0)
# ('Always_Trump', 0)
# ('Aly_Raisman', 0)
# ('Alyssa_Milano', 0)
# ('Alyssafarah', 0)
# ('Alyssafmiller', 0)
# ('AmFamNews', 0)
# ('AmandaHearst', 0)
# ('AmandaJFrasier', 0)
# ('AmandaKessel8', 0)
# ('AmandaSeyfried', 0)
# ('AmandaTMiller', 0)
# ('Amanda_AQW', 0)
# ('Amanda_Balionis', 0)
# ('AmandaaaGee', 0)
# ('Amanresorts', 0)
# ('AmazonKids', 0)
# ('AmazonTeamOrg', 0)
# ('Amb_AlKuwari', 0)
# ('AmbassadorPower', 0)
# ('AmberVenzBox', 0)
# ('AmeliaConcours', 0)
# ('AmericaNewsroom', 0)
# ('AmericanAir', 0)
# ('AmericanWineSoc', 0)
# ('AmericasMorning', 0)
# ('AmherstSports', 0)
# ('AmirArison', 0)
# ('AmityFishCoLtd', 0)
# ('AmyAcker', 0)
# ('AmyDickson', 0)
# ('AmyPurdyGurl', 0)
# ('AmySine', 0)
# ('AmyTrask', 0)
# ('AnaCabrera', 0)
# ('AnaIvanovic', 0)
# ('AnandWrites', 0)
# ('AndraeO_o', 0)
# ('Andre_Reed83', 0)
# ('AndreaFeczko', 0)
# ('AndreaRussett', 0)
# ('AndreaTantaros', 0)
# ('AndreasOberoi', 0)
# ('AndreasOstholt', 0)
# ('AndrewBrandt', 0)
# ('AndrewColtart', 0)
# ('AndrewJA9', 0)
# ('AndrewRiceGolf', 0)
# ('AndrewRudansky', 0)
# ('AndrewTrendell', 0)
# ('AndyGlockner', 0)
# ('AndyMaherSEN', 0)
# ('AndyPlum15', 0)
# ('AndyPuzder', 0)
# ('AndyStanley', 0)
# ('AndySvoboda', 0)
# ('Andy_golf83', 0)
# ('Andyb0930', 0)
# ('Andygordongolf', 0)
# ('AndyjudxUSA', 0)
# ('AngelAlessandra', 0)
# ('Angela_Stanford', 0)
# ('Angeliciaaa', 0)
# ('AngelusNews', 0)
# ('AngieOberholser', 0)
# ('Angiologist', 0)
# ('AniCaribbean', 0)
# ('AnitaAslan', 0)
# ('AnitaMarks', 0)
# ('AnitaPatrickson', 0)
# ('AnnCLauer', 799)
# ('AnnCoulter', 20)
# ('AnnTran_', 0)
# ('AnnaBegenXx', 0)
# ('AnnaKendrick47', 0)
# ('AnnaWhiteley', 0)
# ('Anna_Giaritelli', 0)
# ('Anna_Lesher', 0)
# ('AnnabelRolley', 0)
# ('AnnaliesaQ', 0)
# ('Annalise_Murphy', 0)
# ('AnneDimon', 0)
# ('AnneV', 0)
# ('AnneleeM', 0)
# ('AnnemiekTop', 0)
# ('AnnieLennox', 0)
# ('AnonguIkyase', 0)
# ('AnselElgort', 0)
# ('AntasApparel', 0)
# ('AnthonyBLSmith', 0)
# ('AnthonyBarr', 0)
# ('AnthonyDeGol', 0)
# ('AnthonyDiComo', 0)
# ('Anthony_Ramos1', 0)
# ('Anthonyrendon_6', 0)
# ('AntonioBrown84', 40)
# ('AntonioFrench', 0)
# ('AntonioMurdaca1', 0)
# ('AntonioNickel', 0)
# ('AnwarHadid', 0)
# ('AnzeKopitar', 0)
# ('ApexSportAgency', 0)
# ('Aportzline', 0)
# ('ApostropheReps', 0)
# ('AppSame', 0)
# ('ApprenVoice', 0)
# ('ApprenticeNBC', 0)
# ('AprilBertheneIR', 0)
# ('AprilRossBeach', 0)
# ('Aquatrols', 0)
# ('Aramark', 0)
# ('ArashMarkazi', 0)
# ('ArashiNarucummi', 0)
# ('ArccosGolf', 0)
# ('ArcticMonkeys', 0)
# ('AriFleischer', 0)
# ('AriMelber', 0)
# ('ArianaGrande', 0)
# ('AriannyCeleste', 0)
# ('ArizonaBiltmore', 0)
# ('ArmadaHotel', 0)
# ('ArmanWalia', 0)
# ('ArmaniHotelDXB', 0)
# ('Armintie', 0)
# ('ArmySSGHarper', 0)
# ('AroundTheNFL', 0)
# ('ArranAromatics', 0)
# ('ArronOberholser', 0)
# ('ArtDecoWeekend', 0)
# ('ArtProductionNY', 0)
# ('Arterbery', 0)
# ('ArtesianVA', 0)
# ('ArthelNeville', 0)
# ('ArthurElgort', 0)
# ('ArthurFord', 0)
# ('ArtieShipley3', 0)
# ('AsIfMagazine', 0)
# ('Asendejo', 0)
# ('AshLawnOpera', 0)
# ('AshPratte', 0)
# ('AshRyd', 0)
# ('AshWagner2010', 0)
# ('AshfordPaula', 0)
# ('Ashikaaaaaa', 0)
# ('AshleighMerchan', 0)
# ('AshleyBellR', 0)
# ('AshleyKMayo', 0)
# ('AshleyKamrath', 0)
# ('AshleyRParker', 0)
# ('AshleySaraHaas', 0)
# ('AshlingThompson', 0)
# ('AshworthGolf', 0)
# ('AskAIB', 0)
# ('AskMeAboutEN', 0)
# ('AskMeAboutNAP', 0)
# ('AskMen', 0)
# ('AskMsKaitlin', 0)
# ('AskPaddyPower', 0)
# ('AskVisitDerry', 0)
# ('Ask_WellsFargo', 0)
# ('AstroKatie', 0)
# ('AtTheKnick', 0)
# ('AtTheLamppost', 0)
# ('Athleta', 0)
# ('AthleteHomes', 0)
# ('AthletesBrand', 0)
# ('AthlonDoster', 0)
# ('AtoBoldon', 0)
# ('AudiUK', 0)
# ('AudreyMcClellan', 0)
# ('AudrinaPatridge', 0)
# ('AunoPanama', 0)
# ('AuntBree567', 0)
# ('Ausport', 0)
# ('AussieGrit', 0)
# ('AustinBDaniels', 0)
# ('AustinErnst92', 0)
# ('AustinKarp', 0)
# ('AvengingAngels', 0)
# ('AviaryCocktails', 0)
# ('Aviatrix3', 0)
# ('Avicii', 0)
# ('Avis', 0)
# ('AvivaDrescher', 0)
# ('Avramopoulos', 0)
# ('Ayaan', 0)
# ('AylaBrown', 0)
# ('Ayngelina', 0)
# ('AyrshireFiddle', 0)
# ('AyrshireGolfSCO', 0)
# ('AyrshireHospice', 0)
# ('AyrshireLEADER', 0)
# ('AyrshireTravel', 0)
# ('AyrshireWebsite', 0)
# ('AzaharaGOLF', 0)
# ('Azaleatweetz', 0)
# ('B0wle5y', 0)
# ('BAMcinematek', 0)
# ('BARI_Swimwear', 0)
# ('BARRONTRUMP', 0)
# ('BART_SOMSEN', 0)
# ('BASEtraining', 0)
# ('BASFTurf_us', 0)
# ('BATMALASHES', 0)
# ('BBC', 0)
# ('BBCBreaking', 0)
# ('BBCNews', 0)
# ('BBCNewsAus', 0)
# ('BBCPolitics', 0)
# ('BBCSnooker', 0)
# ('BBCSport', 0)
# ('BBCSpotlightNI', 0)
# ('BBCWorld', 0)
# ('BBC_TopGear', 0)
# ('BBCnireland', 0)
# ('BBMAs', 0)
# ('BBMeebs', 0)
# ('BBQChris76', 0)
# ('BBQNYC', 0)
# ('BBTN', 0)
# ('BBarto18', 0)
# ('BBowlVegas', 0)
# ('BBrooks13', 0)
# ('BCCare', 0)
# ('BCFoxy', 0)
# ('BCP229', 0)
# ('BDT2297', 0)
# ('BDayspring', 0)
# ('BDinSA', 0)
# ('BDubi17', 0)
# ('BESCO22', 0)
# ('BESTERNICK', 0)
# ('BET', 0)
# ('BEverillPGATOUR', 0)
# ('BGSgroupMS', 0)
# ('BHPhotoVideo', 0)
# ('BHaasGolf', 0)
# ('BHowardOfficial', 0)
# ('BIG4Women', 0)
# ('BIGEAST', 0)
# ('BIGEASTchamps', 0)
# ('BJMontana', 0)
# ('BKRichey', 0)
# ('BKoepka', 0)
# ('BLAIRONEAL', 0)
# ('BLKDNM', 0)
# ('BMRisingTV', 0)
# ('BMS_ThadCastle', 0)
# ('BMWPGA', 0)
# ('BMacatee', 0)
# ('BMooners', 0)
# ('BOIbusiness', 0)
# ('BR1GATOR', 0)
# ('BRAINTRUSTbuzz', 0)
# ('BRGolfer', 0)
# ('BR_Insights', 0)
# ('BR_MLB', 0)
# ('BR_TheFuture', 0)
# ('BTJHarrison', 0)
# ('BTNDaveRevsine', 0)
# ('BThompsonTurf', 0)
# ('BUAMIMMj', 0)
# ('BUrlacher54', 0)
# ('BVCCproshop', 0)
# ('BVUAthletics', 0)
# ('BW', 0)
# ('BWiesberger', 0)
# ('B_Chowder', 0)
# ('B_EGolfSociety', 0)
# ('B_Paladino', 0)
# ('BabesForTrump', 0)
# ('BabouCeesay', 0)
# ('BabsonAthletics', 0)
# ('BabyAnimalPics', 0)
# ('Baccarat', 0)
# ('BaccaratHotels', 0)
# ('BacheloretteABC', 0)
# ('BadalDad', 0)
# ('BadgerClubGolf', 0)
# ('BagSnob', 0)
# ('BahaMarResorts', 0)
# ('BaileJason', 0)
# ('BaileyMosierGC', 0)
# ('Baileybr1', 0)
# ('BainGolfPGA', 0)
# ('Bakari_Sellers', 0)
# ('BalaGolfClub', 0)
# ('BallengeeGroup', 0)
# ('BallparkArt', 0)
# ('BallysAC', 0)
# ('Balmain', 0)
# ('BaltGetty', 0)
# ('BanchoryLodge', 0)
# ('BarPassChi', 0)
# ('BarRescue', 0)
# ('BarSiena', 0)
# ('BarackObama', 0)
# ('BarassieProShop', 0)
# ('BarbaraCorcoran', 0)
# ('BarbaraDickson', 0)
# ('BarbaraJWalters', 0)
# ('BarefootResort', 0)
# ('Barkovsasha95', 0)
# ('Barnbougle', 0)
# ('BarneysNY', 0)
# ('BarringtonsLK', 0)
# ('BarsAndMelody', 0)
# ('BarstoolSSOTD', 0)
# ('BarstoolTrent', 0)
# ('BassProLegends', 0)
# ('BatsonClay', 0)
# ('BauerHockey', 0)
# ('BautistaAgut', 0)
# ('BaySean', 0)
# ('BayerGolf', 0)
# ('BazaarUK', 0)
# ('Bazaar_nl', 0)
# ('BballcoachNY', 0)
# ('Bcfrx', 0)
# ('BdotAdot5', 0)
# ('BeCul001', 0)
# ('BePositiveFdn', 0)
# ('BeSocialEdu', 0)
# ('Beany25', 0)
# ('BeatrizRecari', 0)
# ('BeauStack', 0)
# ('Beauty411', 0)
# ('BeautyBlogger', 0)
# ('BeautyBuzzDaily', 0)
# ('BeautyEditorNYC', 0)
# ('BeautyPerfect__', 0)
# ('BeautyintheBag', 0)
# ('BeavrCreekCalls', 0)
# ('BebeRexha', 0)
# ('BecFloodGolf', 0)
# ('BecauseImFreida', 0)
# ('BeccaBaileyGolf', 0)
# ('BeccaMorrice_', 0)
# ('BeckleyMason', 0)
# ('BecknerLee', 0)
# ('BeckyBerns', 0)
# ('BeefGolf', 0)
# ('BeefyBotham', 0)
# ('BeefyDisney', 0)
# ('BeingChia', 0)
# ('BekahMackey', 0)
# ('BekahsTravels', 0)
# ('BelenMozo', 0)
# ('BelfairAgronomy', 0)
# ('BelfastFestival', 0)
# ('BellaRojo', 0)
# ('BellaTwins', 0)
# ('Bella_Collina', 0)
# ('Bellerzkleinbe', 0)
# ('BelmontAcademy_', 0)
# ('Belonika', 0)
# ('BenAlberstadt', 0)
# ('BenCadiouJdgolf', 0)
# ('BenFortesMayer', 0)
# ('BenHogan', 0)
# ('BenHoganAward', 0)
# ('BenHurMovie', 0)
# ('BenSasse', 0)
# ('BenTrodd', 0)
# ('Ben_Baskin', 0)
# ('Ben_Martin87', 0)
# ('Ben_Shear', 0)
# ('BenchmarkEmail', 0)
# ('BenderGloves', 0)
# ('BenedictEvans', 0)
# ('Benhberger', 0)
# ('Benioff', 0)
# ('BenjLerer', 0)
# ('Benjalvarado', 0)
# ('BenjySarlin', 0)
# ('Bennbarham', 0)
# ('BennyHunnaa', 0)
# ('BennysChopHouse', 0)
# ('Bergdorfs', 0)
# ('BergstromKevin', 0)
# ('BernardGoldberg', 0)
# ('BernieKosarQB', 0)
# ('BernieMerry', 0)
# ('BernieNajarGolf', 0)
# ('BernieSanders', 0)
# ('BerryVikings', 0)
# ('BeschlossDC', 0)
# ('BespokenNYC', 0)
# ('BestBitsWorld', 0)
# ('BestHairstyIes', 0)
# ('BestProAdvice', 0)
# ('BestSpaHotels1', 0)
# ('BestofGemini', 0)
# ('BestofLibra', 0)
# ('BestofNewYork', 0)
# ('BestofPisces', 0)
# ('BethAllenGolf', 0)
# ('BethCianciolo', 0)
# ('BethHMcLeod', 0)
# ('BethOnY100', 0)
# ('BethRigby', 0)
# ('BethsTable', 0)
# ('BetteMidler', 0)
# ('BetterWaterSoil', 0)
# ('BettinaPrentice', 0)
# ('BettinardiGolf', 0)
# ('BettyMWhite', 0)
# ('BeyondMyDoor', 0)
# ('BezChristiaan', 0)
# ('Bharper3407', 0)
# ('BianchinLuisa', 0)
# ('BieberSwag_JB', 0)
# ('BiffyClyro', 0)
# ('BigBreak', 0)
# ('BigEasyDurban', 0)
# ('BigHeadSports', 0)
# ('BigKennyTV', 0)
# ('BigMossGolf', 0)
# ('BigRedBiography', 0)
# ('BighornGolfClub', 0)
# ('BillBarrowAP', 0)
# ('BillBeale', 0)
# ('BillFedder', 0)
# ('BillGates', 0)
# ('BillGriffeth', 0)
# ('BillHemmer', 0)
# ('BillKristol', 0)
# ('BillMoyersHQ', 0)
# ('BillNeelyNBC', 0)
# ('BillNicholsDMN', 0)
# ('BillRMcDermott', 0)
# ('BillSimmons', 0)
# ('BillWeirCNN', 0)
# ('BillZucker', 0)
# ('BillionEstates', 0)
# ('BillionaireUniv', 0)
# ('BillyBrath', 0)
# ('BillyCrystal', 0)
# ('BillyHo_Golf', 0)
# ('BillyHurley3', 0)
# ('BindiIrwin', 0)
# ('BioSteelSports', 0)
# ('BirchmoreGroup', 0)
# ('BirdieBox', 0)
# ('BirdieFireGolf', 0)
# ('BirdiesForBrave', 0)
# ('BishopCEBlake', 0)
# ('BishopsGateGA', 0)
# ('Bitmoji', 0)
# ('BizBash', 0)
# ('BizBashLive', 0)
# ('BlackGirlsGolf', 0)
# ('BlackburnGolf', 0)
# ('Blackout_Barbie', 0)
# ('BlaineZuck', 0)
# ('BlairWalsh3', 0)
# ('BlakeHankins121', 0)
# ('Blake_SIn', 0)
# ('Blake_alex95', 0)
# ('BlandCooper', 0)
# ('BlansitTaylor', 0)
# ('BlasNahEireann', 0)
# ('BleacherReport', 20)
# ('Blendle', 0)
# ('Blisscharity', 0)
# ('BlitzBokke', 0)
# ('Blonde_Politico', 0)
# ('BloombergTV', 0)
# ('BloomfieldGolf', 0)
# ('BlueJacketsNHL', 0)
# ('BlueLivesNYC', 0)
# ('Blumenherst', 0)
# ('Bmcreynolds28', 0)
# ('BoA_GT', 0)
# ('BoDietl', 0)
# ('BoF', 0)
# ('BoHoag', 0)
# ('BoSnerdley', 0)
# ('BoardRoomMag', 0)
# ('BobHarig', 0)
# ('BobKnakal', 0)
# ('BobKoepka', 0)
# ('BobPapa_NFL', 0)
# ('BobPhilionCPG', 0)
# ('BobSocci', 0)
# ('BobWeeksTSN', 0)
# ('BobWeir', 0)
# ('BobbyGatesGolf', 0)
# ('BobbyJindal', 0)
# ('Boeing', 0)
# ('BoeingAirplanes', 0)
# ('BoeingCareers', 0)
# ('BoggsPGA', 0)
# ('BolsGenever', 0)
# ('BombayTEXT', 0)
# ('BomberSports', 0)
# ('BonesHR', 0)
# ('BonjocGolf', 0)
# ('BonnieCreamer', 0)
# ('BonnieFuller', 0)
# ('BonnieWeeGolf', 0)
# ('Boo_Radleey', 0)
# ('BoomBoomGolf1', 0)
# ('BoomerWells33', 0)
# ('BoomerandCarton', 0)
# ('BootCampaign', 0)
# ('BootRanch', 0)
# ('BordersCollege', 0)
# ('BorgataAC', 0)
# ('BorisEP', 0)
# ('BostonChildrens', 0)
# ('BostonGlobe', 0)
# ('BostonRob', 0)
# ('BoudewijnRoell', 0)
# ('BouleyBotanical', 0)
# ('Bourdain', 0)
# ('Bowen12', 0)
# ('BoyEpic', 0)
# ('BoysEatScotland', 0)
# ('BozeForged', 0)
# ('Bpgolfchannel', 0)
# ('BracewellFRG', 0)
# ('BracewellLaw', 0)
# ('BradEllisPiano', 0)
# ('BradFaxon', 0)
# ('BradFritsch', 0)
# ('BradRoby_1', 0)
# ('BradThor', 0)
# ('BraddJaffy', 0)
# ('BradleySKlein', 0)
# ('BradleyScott1', 0)
# ('BradsGolfBag', 0)
# ('BrandNewMatter', 0)
# ('BrandelChamblee', 0)
# ('BrandenGrace', 0)
# ('BrandiGlanville', 0)
# ('BrandoManzo', 0)
# ('BrandonLeague43', 0)
# ('BrandonMStone', 0)
# ('BrandonMabe013', 0)
# ('BrandonTierney', 0)
# ('BrandtSnedeker', 0)
# ('BrantHarry', 0)
# ('BrataneWhite', 0)
# ('Bravotv', 0)
# ('BrawleyNolte', 0)
# ('BraxtonMiller5', 0)
# ('BreKennedy', 0)
# ('BreLoucksGolf', 0)
# ('BreWinburn', 0)
# ('BreaAnnWeiss', 0)
# ('Breaking911', 0)
# ('BreakingNews', 0)
# ('BreakthroughBC', 0)
# ('BreakwaterCHI', 0)
# ('BreenGroup4', 0)
# ('BreitbartLondon', 0)
# ('BreitbartNews', 0)
# ('BrenDLV', 0)
# ('BrendanAMurphy', 197)
# ('Brendan_Steele', 0)
# ('BrendonTodd', 0)
# ('Brendon_Thomas', 0)
# ('BrentCSN', 0)
# ('BrentHBaker', 0)
# ('BrentIto4', 0)
# ('BrentLong2', 0)
# ('BretBaier', 0)
# ('BretSabes', 0)
# ('BrettskiPeggs', 0)
# ('BrewDock', 0)
# ('Brewster50', 0)
# ('Breznican', 0)
# ('Brialalexi', 0)
# ('BrianBirneyGCS', 0)
# ('BrianCHouston', 0)
# ('BrianCostaWSJ', 0)
# ('BrianDEvans', 0)
# ('BrianDawkins', 0)
# ('BrianEdwards63', 0)
# ('BrianEntin', 0)
# ('BrianFreeswick', 0)
# ('BrianGa13', 0)
# ('BrianGaffneyPGA', 0)
# ('BrianGayPGA', 0)
# ('BrianHammons', 0)
# ('BrianLVickers', 0)
# ('BrianMahoneyMGA', 0)
# ('BrianNorgard', 0)
# ('BrianODriscoll', 0)
# ('BrianOReilly13', 0)
# ('BrianSunderhaus', 0)
# ('Brian_K_Lewis', 0)
# ('BriannaSciara', 0)
# ('Brianteta', 0)
# ('BriarcliffManor', 0)
# ('BriceGarnett', 0)
# ('BridalInspo', 0)
# ('BrideStyle782', 0)
# ('Bridgestone', 0)
# ('Bridget_Linton', 0)
# ('BrielleCyclery', 0)
# ('BrighamWomens', 0)
# ('Brince_P', 0)
# ('BringerOfRain20', 0)
# ('BrinleyBruton', 0)
# ('Brioni_Official', 0)
# ('BrionnaB_', 0)
# ('BritCharde', 0)
# ('BritishRedCross', 0)
# ('BritishVogue', 0)
# ('BrittBurkie', 0)
# ('BrittHebert84', 0)
# ('BrittSkyHigh', 0)
# ('Brittany1golf', 0)
# ('BrittanyFurlan', 0)
# ('Brittanysnow', 0)
# ('BrittneyPalmer', 0)
# ('BroadFoundation', 0)
# ('BroadRunGC', 0)
# ('Broadsheet_Melb', 0)
# ('BrockMackenzie', 0)
# ('BrockStoneham', 0)
# ('BrodyJenner', 0)
# ('BronxPinstripes', 0)
# ('Bronxmedia', 0)
# ('BrookLake_CC', 0)
# ('BrookePancake', 0)
# ('Brookeg12', 0)
# ('BrooklynDecker', 0)
# ('BrooksBrothers', 0)
# ('Brooks_Dunn', 0)
# ('BrotherMob', 0)
# ('BrownBCI', 0)
# ('BrowningMachine', 0)
# ('Browns', 0)
# ('BruceArians', 0)
# ('BruceBeck4NY', 0)
# ('Brudyboy', 0)
# ('BrunoMars', 0)
# ('BryanCranston', 0)
# ('BryanFenley', 0)
# ('BryanHoch', 0)
# ('BryanRobertson_', 0)
# ('BryanVoltaggio', 0)
# ('BryceLyle1', 0)
# ('BrydgeMack', 0)
# ('BubbaWallace', 0)
# ('Bubbys', 0)
# ('Buc_fever', 0)
# ('Buccigross', 0)
# ('Bud1974', 0)
# ('BudCauley', 0)
# ('Buddywilltravel', 0)
# ('BuhlPhilipp', 0)
# ('BuhoCantina', 0)
# ('BuildItBro', 0)
# ('BumbleCricket', 0)
# ('BunkerStyle', 0)
# ('BunkeredOnline', 0)
# ('BunkersParadise', 0)
# ('BurgessOwens', 0)
# ('BurghleyGolf', 0)
# ('Burieberry', 0)
# ('BurneB0t', 0)
# ('Burner05', 0)
# ('BurningPounds', 0)
# ('BurrRealEstate', 0)
# ('BushHomer', 0)
# ('Buster_ESPN', 0)
# ('ButtaCupBaby69', 0)
# ('Butterflydiary', 0)
# ('BuzzFeed', 0)
# ('BuzzworksLife', 0)
# ('Bvallison', 0)
# ('Bville_News', 0)
# ('Bwagz54', 0)
# ('ByJoeFleming', 0)
# ('ByRickBrown', 0)
# ('ByTimGraham', 0)
# ('ByeongHunAn', 0)
# ('ByrdyTweetTweet', 0)
# ('ByronYork', 0)
# ('C0l13n', 0)
# ('C21AAANorth', 0)
# ('CABBSTUART', 0)
# ('CAMCONevada', 0)
# ('CASEnSHAKE', 0)
# ('CA_Schwartzel', 0)
# ('CAdolff', 0)
# ('CAuchere', 0)
# ('CB2tweets', 0)
# ('CBNNews', 0)
# ('CBS', 0)
# ('CBS12', 0)
# ('CBSNewYork', 0)
# ('CBSNews', 0)
# ('CBSPittsburgh', 0)
# ('CBSSports', 0)
# ('CBSThisMorning', 0)
# ('CBSiAdvMedia', 0)
# ('CBrown_3', 0)
# ('CByrneBolling', 0)
# ('CCChampions', 0)
# ('CCMediterraneo', 0)
# ('CCRA_Travel', 0)
# ('CCRInitiative', 0)
# ('CCSTPorg', 0)
# ('CCTigers', 0)
# ('CC_Sabathia', 0)
# ('CClovesgolf', 0)
# ('CDGAGolf', 0)
# ('CDNMomBlog', 0)
# ('CDWgolf', 0)
# ('CEOPGA', 0)
# ('CFD22', 0)
# ('CFDA', 0)
# ('CFL_PR', 0)
# ('CF_Borriol', 0)
# ('CF_Foundation', 0)
# ('CFashionista', 0)
# ('CGAgolf1909', 0)
# ('CH3golf', 0)
# ('CHANEL', 0)
# ('CHASEFIFTYFOUR', 0)
# ('CHA_Alliance', 0)
# ('CHLAKidSafety', 0)
# ('CIA', 0)
# ('CIRonline', 0)
# ('CJADOYLE', 0)
# ('CJBerry21', 0)
# ('CJDeuce_', 0)
# ('CJG1977', 0)
# ('CJToledano', 0)
# ('CJ_Bertram', 0)
# ('CKGolferChic', 140)
# ('CLAIREECOOPER', 0)
# ('CLDoucette', 0)
# ('CLIQJEWELRY', 0)
# ('CLPdub', 0)
# ('CLUSports', 0)
# ('CLewandowski_', 419)
# ('CMAA', 0)
# ('CMEGroupLPGA', 0)
# ('CMO_com', 0)
# ('CMPunk', 0)
# ('CMT', 0)
# ('CMcCormickGolf', 0)
# ('CMoralesCNN', 0)
# ('CNBC', 0)
# ('CNFashion', 0)
# ('CNHSwrestling', 0)
# ('CNJosephson15', 0)
# ('CNN', 0)
# ('CNNCareers', 0)
# ('CNNFilms', 0)
# ('CNNLivingGolf', 0)
# ('CNNMoney', 0)
# ('CNNOpinion', 0)
# ('CNNOriginals', 0)
# ('CNNPhotos', 0)
# ('CNNPolitics', 80)
# ('CNNSitRoom', 0)
# ('CNNSpecReport', 0)
# ('CNNStyle', 0)
# ('CNNTonight', 0)
# ('CNNValencia', 0)
# ('CNNWade', 0)
# ('CNN_Oppmann', 0)
# ('CNNent', 0)
# ('CNNnewsroom', 0)
# ('CNTraveler', 0)
# ('COSAGOV', 0)
# ('CP3', 0)
# ('CPAC', 0)
# ('CPSightseeing', 0)
# ('CPhasHeart', 0)
# ('CRTurnberry', 40)
# ('CRUgolf', 0)
# ('CR_UK', 0)
# ('CRayPR', 0)
# ('CRominger_Golf', 0)
# ('CSGC_GCS', 0)
# ('CSHathletics', 0)
# ('CSNMA', 0)
# ('CSkyLuxuryHotel', 0)
# ('CSteel92', 0)
# ('CTHURST25', 0)
# ('CTIAShows', 0)
# ('CTMirrorPaz', 0)
# ('CTowersCBS', 0)
# ('CTyrrellMedinah', 0)
# ('CUNTNEYLOVE', 0)
# ('CU_DodgeCollege', 0)
# ('CVancheri', 0)
# ('CWPAWaterPolo', 0)
# ('CWSbocoIRL', 0)
# ('CY24_7', 0)
# ('C_McNulty', 0)
# ('C_R_LowndesGolf', 0)
# ('CaddyFluff', 0)
# ('Cadillac', 0)
# ('CaesarsAC', 0)
# ('CafeMilanoDC', 0)
# ('CairngormMtn', 0)
# ('Caitlyn_Jenner', 0)
# ('CalMensGolf', 0)
# ('CaledoniaPutter', 0)
# ('Calexander62', 0)
# ('CalhounJacket', 0)
# ('CaliforniaPanda', 0)
# ('CallawayGolf', 40)
# ('CallawayGolfPR', 0)
# ('CalvinHarris', 0)
# ('CalvinKnights', 0)
# ('CamAtkinson13', 0)
# ('CamTringalePGA', 0)
# ('CambisGuillaume', 0)
# ('Cambridge_Uni', 0)
# ('CameronCRussell', 0)
# ('CameronMorfit', 0)
# ('Cameronvdburgh', 0)
# ('CamilaMTV', 0)
# ('CamillaAkrans', 0)
# ('CamiloVillegasR', 0)
# ('CaminosDivinos', 0)
# ('Campus_Cuties', 0)
# ('CanUlearn2Fern', 0)
# ('CanaanRubin', 0)
# ('CancerFilm', 0)
# ('Cancer_Cell', 0)
# ('CandaceETaylor', 0)
# ('Candace_Parker', 0)
# ('CandiceAccola', 0)
# ('Canemom1', 0)
# ('Cannonball63', 0)
# ('Cannonbawlz', 0)
# ('CantStumpTrump1', 0)
# ('CanyonRanch', 0)
# ('CapeLondonWine', 0)
# ('Captain47', 0)
# ('CaptainObvious', 0)
# ('CaraGroupTravel', 0)
# ('CaraMiaConnolly', 0)
# ('CaraRobbo', 0)
# ('Caradelevingne', 0)
# ('Cardale7_', 0)
# ('CareerGolf', 0)
# ('CarinaSpera', 0)
# ('CarlDaikeler', 0)
# ('CarlHigbie', 0)
# ('CarlPaulsonGolf', 0)
# ('Carl_C_Icahn', 0)
# ('Carl_Cunard', 0)
# ('CarlaKJohnson', 0)
# ('CarleyC07', 0)
# ('CarliLloyd', 0)
# ('CarlingNolan', 0)
# ('CarlosGreer', 0)
# ('CarltonGebbia13', 0)
# ('CarlyBooth92', 0)
# ('CarlyFiorina', 0)
# ('CarmenOrtega1', 0)
# ('CaroIssa', 0)
# ('CaroMasson', 0)
# ('Carocci44', 0)
# ('Carodemaigret', 0)
# ('CarolCNN', 0)
# ('CarolanTurlough', 0)
# ('Carolde', 0)
# ('CarolinasJunior', 0)
# ('CarolinePalmer', 0)
# ('CarolineRhea', 0)
# ('CarolineSzwed', 0)
# ('CarolynMAndrews', 0)
# ('CarrGolfTravel', 0)
# ('CarrollDoherty', 0)
# ('CarsonDaly', 0)
# ('CarsonKamps', 0)
# ('CarterCBS', 0)
# ('CasaReynaMex', 0)
# ('CaseyDykes', 0)
# ('CaseyHoban', 0)
# ('CaseyNeistat', 0)
# ('Cash10X', 0)
# ('CashSports', 0)
# ('CasinoGetaways', 0)
# ('CassidyDumbauld', 0)
# ('CastiglioneYael', 0)
# ('CastlebarHQ', 0)
# ('CatBoogie89', 0)
# ('CatchNY', 0)
# ('CatieEvans', 0)
# ('CatieValleau', 0)
# ('Cavalier6', 0)
# ('CavallinoPizza', 0)
# ('CavsFredMcLeod', 0)
# ('Cedvongerichten', 0)
# ('CeeWilliams1', 0)
# ('CeeofCee', 0)
# ('CelebApprentice', 0)
# ('CelebStyleGuide', 0)
# ('CelebgrittyMag', 0)
# ('CelebratedEmer', 0)
# ('CelebrityAgents', 0)
# ('CelesteAbdel', 0)
# ('CelticGolf', 0)
# ('CentennialConf', 0)
# ('CentralParkNYC', 0)
# ('CentraldeBrazil', 0)
# ('Centro', 0)
# ('Cernovich', 0)
# ('Ces_HV', 0)
# ('Cfcompton', 0)
# ('Ch3Pga', 0)
# ('ChaChaMatchaNYC', 0)
# ('ChadBphotog', 0)
# ('ChadEhrnsberger', 0)
# ('ChadSDay', 0)
# ('Chad_Hurley', 0)
# ('ChalhoubGc', 0)
# ('Challenge_Tour', 0)
# ('ChambersBayGolf', 0)
# ('ChambleeJr', 0)
# ('ChampionsLeague', 0)
# ('ChampionsTour', 0)
# ('Chantagold', 0)
# ('ChapKiscoPatch', 0)
# ('ChapmanNews', 0)
# ('ChapmanU', 0)
# ('ChapterOneDub', 0)
# ('CharJaneMer', 0)
# ('CharSteakLounge', 0)
# ('CharValkeniers', 0)
# ('CharissaT', 0)
# ('CharleneWhite', 0)
# ('CharlesHumbard', 0)
# ('CharlesJenkins7', 0)
# ('CharlesMBlow', 0)
# ('CharlesOgletree', 0)
# ('Charley_Rixton', 0)
# ('CharlieDaniels', 0)
# ('CharlieParsons_', 0)
# ('CharlieRymerGC', 0)
# ('CharlieWyett', 0)
# ('Charlie_Carver', 0)
# ('Charlieleduff', 0)
# ('CharlottCordes', 0)
# ('CharmaiineHazel', 0)
# ('Chartwellmag', 0)
# ('Chase', 0)
# ('ChaseAlllison', 0)
# ('ChauntieKay', 0)
# ('ChayzzDevyant', 0)
# ('Chazzyboy79', 0)
# ('CheersVA', 0)
# ('ChefCalias', 0)
# ('ChefDavidBurke', 0)
# ('ChefJoeMurphy', 0)
# ('Chef_Rouge', 0)
# ('ChelsHope1', 0)
# ('ChelsTurnerrr', 0)
# ('ChelseaClinton', 0)
# ('ChelseaHover', 0)
# ('Chelseashow', 0)
# ('Cherokee_Valley', 0)
# ('CherryDJM', 0)
# ('CherylBurke', 0)
# ('CherylForbergRD', 0)
# ('CherylWillman', 0)
# ('CheshireGDG', 0)
# ('Cheyenne_Woods', 0)
# ('ChiSportsComm', 0)
# ('ChiStyleWed', 0)
# ('ChiaraFerragni', 0)
# ('ChicBuds', 0)
# ('ChicagoMaroons', 0)
# ('Chicago_Bandits', 0)
# ('ChickenMan3010', 0)
# ('Chickillo71', 0)
# ('ChiefDigOfficer', 0)
# ('Chiefs', 0)
# ('China_Chow', 0)
# ('ChineseTheatres', 0)
# ('ChipBeck59', 0)
# ('ChipBrown', 0)
# ('Chips_Aloi', 0)
# ('ChisouLondon', 0)
# ('ChloeGMoretz', 0)
# ('Chloe_Caldwell', 0)
# ('Chloleurquin', 0)
# ('ChooseEither', 0)
# ('ChopperBikerDog', 0)
# ('ChoupettesDiary', 0)
# ('Chris3Wood', 0)
# ('Chris80Newman', 0)
# ('ChrisAriens', 0)
# ('ChrisAugust', 0)
# ('ChrisBerend', 0)
# ('ChrisChristie', 0)
# ('ChrisComoGolf', 0)
# ('ChrisCoons', 0)
# ('ChrisCuomo', 0)
# ('ChrisDBowen', 0)
# ('ChrisDiMarco', 0)
# ('ChrisDunhamJr', 0)
# ('ChrisEssner', 0)
# ('ChrisEvans', 0)
# ('ChrisFranjola', 0)
# ('ChrisGibsonNY', 0)
# ('ChrisGlynn4', 0)
# ('ChrisGreenPics', 0)
# ('ChrisHemmerich', 0)
# ('ChrisHiggins10', 0)
# ('ChrisLaibleCBS', 0)
# ('ChrisLicht', 0)
# ('ChrisLinke88', 0)
# ('ChrisMcCardell', 0)
# ('ChrisMcKendry', 0)
# ('ChrisMurray627', 0)
# ('ChrisOHagan87', 0)
# ('ChrisPalmerNBA', 0)
# ('ChrisSnyderFox', 0)
# ('ChrisStigall', 0)
# ('ChrisStirewalt', 0)
# ('ChrisStroudPGA', 0)
# ('ChrisTh97836277', 0)
# ('ChrisTidland', 0)
# ('ChrisUmpierre', 0)
# ('ChrisWarcraft', 0)
# ('ChrisWegnerPGA', 0)
# ('Chris_Broussard', 0)
# ('Chris_Lammstein', 0)
# ('Chris_Simonin', 0)
# ('Chris_Taiwan', 0)
# ('Chris_WatsonPGA', 0)
# ('Chris_arnade', 0)
# ('ChrisisSingin', 0)
# ('Chrisspymakeup', 0)
# ('Christi_Paul', 0)
# ('ChristianCinema', 0)
# ('ChristianWhiton', 0)
# ('Christian_Zamo', 0)
# ('ChristinaFNP', 0)
# ('ChristinaGCheng', 0)
# ('ChristinaGra', 0)
# ('Christina_Corso', 0)
# ('ChristineDByers', 0)
# ('ChristophrWood', 0)
# ('ChristyTRIs', 0)
# ('Chromeo', 0)
# ('ChrsFleming', 0)
# ('Chryzluh', 0)
# ('ChuckGrassley', 0)
# ('ChuckVine', 0)
# ('CiCiAdams_', 0)
# ('CiGmBankRoll', 0)
# ('CiaoBambino', 0)
# ('CiarPorciani', 0)
# ('CindyBlackwel12', 0)
# ('CindyChafian', 0)
# ('CindyCrawford', 0)
# ('CindyNWatts', 0)
# ('Cinemax', 0)
# ('Cipriani', 0)
# ('CisarTurfDoc', 0)
# ('CitiOpen', 0)
# ('CitizenFemme', 0)
# ('Citizens_United', 0)
# ('CitronHollie', 0)
# ('CityCenterDC', 0)
# ('CityOfLasVegas', 0)
# ('CityYear', 0)
# ('CityYearLA', 0)
# ('CityofKentOhio', 0)
# ('CityofMiami', 0)
# ('CiudadPty', 0)
# ('ClaireGroden', 0)
# ('ClaireShipman', 0)
# ('ClareFM', 0)
# ('ClareMiller30', 0)
# ('ClareTourism', 0)
# ('ClarissaChicago', 0)
# ('ClarkBentson', 0)
# ('Clarksflorist', 0)
# ('ClassicPict', 0)
# ('ClaudiaTorrens', 0)
# ('Clavizzao', 0)
# ('ClayWalker', 0)
# ('Clay_Bill_Clay', 0)
# ('ClaytonESPN', 0)
# ('ClaytonKersh22', 0)
# ('ClaytonMorris', 0)
# ('Clearly_BallLyf', 0)
# ('CleveFoundation', 0)
# ('ClevelandClinic', 0)
# ('ClevelandGolf', 0)
# ('ClevelandGolfEu', 0)
# ('ClevelandPlus', 0)
# ('CliffAYoung', 0)
# ('CliftonLeaf', 0)
# ('Clijsterskim', 0)
# ('ClimateDesk', 0)
# ('ClippersStore', 0)
# ('CloisterTweets', 0)
# ('CloudberryRoque', 0)
# ('ClubBenchmark', 0)
# ('ClubCateringPro', 0)
# ('ClubDTL', 0)
# ('ClubProGuy', 0)
# ('Club_and_Resort', 0)
# ('ClydeSoFly10', 0)
# ('Cmiddaughgolf', 40)
# ('CoachBrianKelly', 0)
# ('CoachDuzzPittFB', 0)
# ('CoachFick', 0)
# ('CoachJimmyDykes', 0)
# ('CoachJoeyD', 0)
# ('CoachKDiaz', 0)
# ('CoachLockey', 0)
# ('CoachMcElwain', 0)
# ('CoachMotto', 0)
# ('CoachRWise', 0)
# ('CoachRec_10', 0)
# ('CoachTomHerman', 0)
# ('CoachVrabel50', 0)
# ('Coach_Davies', 0)
# ('CoachesHotSeat', 0)
# ('CobberSID', 0)
# ('CocaCola', 0)
# ('CocaCola_GB', 0)
# ('CochitoCruz', 0)
# ('Cod_Rob', 0)
# ('CodeAud', 0)
# ('CoeAthletics', 0)
# ('Coelsss', 0)
# ('Coen_DbPassion', 0)
# ('Col_Isaac', 0)
# ('ColbyCohen36', 0)
# ('ColdChisel75', 0)
# ('ColemanMcDowell', 0)
# ('ColinJost', 0)
# ('ColinWeddings', 0)
# ('Collective_B', 0)
# ('ColleenNBC12', 0)
# ('CollinsworthPFF', 0)
# ('ColmCampbell87', 0)
# ('ColtKnost', 0)
# ('Colts', 0)
# ('ColtsNeckHSgolf', 0)
# ('ColtsNeckTalk', 0)
# ('Columbia', 0)
# ('ColumbiaMed', 0)
# ('ComedyCentral', 0)
# ('Comic_Con', 0)
# ('CommishDiaz', 0)
# ('ComplexMag', 0)
# ('Complex_Sports', 0)
# ('ConLentz', 0)
# ('ConSchwartz', 0)
# ('ConanOBrien', 0)
# ('Concierge4Pros', 0)
# ('ConcordRecords', 0)
# ('Concur', 0)
# ('CondeMatt', 0)
# ('CondoleezzaRice', 0)
# ('CondrensGolf', 0)
# ('CongHuelskamp', 0)
# ('CongressmanDan', 0)
# ('ConnCollege', 0)
# ('Conner__Stewart', 0)
# ('ConnorFranta', 0)
# ('ConnorSchell', 0)
# ('Connor_UA', 0)
# ('ConnorsCure', 0)
# ('ConnosaurausRex', 0)
# ('ConorGaffey', 0)
# ('ConormPowell', 0)
# ('ConservAmerica', 0)
# ('ConstantineM', 0)
# ('Cookies4kids', 0)
# ('CoolClubs', 0)
# ('CoolEngel', 0)
# ('CoolestLifeHack', 0)
# ('CoopersLaw', 0)
# ('Corey_Maggette', 0)
# ('CornelWest', 0)
# ('CorneliusSJr', 0)
# ('Cornell', 0)
# ('CortesLatino', 0)
# ('CoryBooker', 0)
# ('CoryBradburn', 0)
# ('CoryGardner', 0)
# ('CounterJihadUS', 0)
# ('CountyLouthGC', 0)
# ('CoupledFOX', 0)
# ('CourtCrawfFBN', 0)
# ('CourtsideFilms', 0)
# ('CowboyJoeDesign', 0)
# ('CowherCBS', 0)
# ('Cradlz', 0)
# ('CraigCampbell60', 0)
# ('CraigCaplan', 0)
# ('CraigCassells01', 0)
# ('CraigDolch', 0)
# ('CraigGriffinCo', 0)
# ('CraigKarmin', 0)
# ('CraigSBPA', 0)
# ('Craig_Dennett', 0)
# ('CrainsCleveland', 0)
# ('CrainsNewYork', 0)
# ('Crashingtv', 0)
# ('CreeBulb', 0)
# ('Creed', 0)
# ('CreemMag', 0)
# ('CrimeVictimsOrg', 0)
# ('CrimesofUS', 0)
# ('CrisMedina', 0)
# ('Crisanthemum_', 0)
# ('Cristiano', 0)
# ('Cronikeys', 0)
# ('Crooked_Flight', 0)
# ('CrossFit', 0)
# ('CrossFitGames', 0)
# ('Crossfire', 0)
# ('Crowdfire', 0)
# ('CruiseReport', 0)
# ('Crystal_Arnold', 0)
# ('Cubs', 0)
# ('CubsJoeMadd', 0)
# ('CucinaCiano', 0)
# ('CuffyMeh', 0)
# ('CulinaPhilosoph', 0)
# ('Cullasaja_Club', 0)
# ('CullodenHouse', 0)
# ('Culzeancastle', 0)
# ('CurbedHamptons', 0)
# ('CureAlzheimers', 0)
# ('CureCancerNow', 0)
# ('CurrieCupRugby', 0)
# ('CurtisHill_IN', 0)
# ('CurtisLuck6', 0)
# ('CurtisReedGolf', 0)
# ('Cuscowilla', 0)
# ('Custo_Barcelona', 0)
# ('CustomsBorder', 0)
# ('Cut4', 0)
# ('CuteEmergency', 0)
# ('CuttingBoardCo', 0)
# ('CuyahogaGOP', 0)
# ('CvilleUnCorked', 0)
# ('CvilleWineFest', 0)
# ('CyberExaminer', 0)
# ('CydBee', 0)
# ('CyndiRamirez', 0)
# ('CynthiaLIVE', 0)
# ('CynthiaLoboEsq', 0)
# ('D19J', 0)
# ('D29Gillian', 140)
# ('D8Iveta', 0)
# ('DAPoints', 0)
# ('DARRENHARDY', 0)
# ('DASRecruiter', 0)
# ('DAVID_LYNCH', 0)
# ('DBerko', 0)
# ('DCCelebrity', 0)
# ('DCMagazineML', 0)
# ('DCPoliceDept', 0)
# ('DCUCoaching', 0)
# ('DCarpenter29', 0)
# ('DDFIrishOpen', 0)
# ('DDonigerGolf', 0)
# ('DG_GolfNews', 0)
# ('DHBerman', 0)
# ('DHRisher', 0)
# ('DIARYdirectory', 0)
# ('DIYBedroom', 0)
# ('DIac1127', 0)
# ('DIceman24', 0)
# ('DJBIGGIEJSODMG', 0)
# ('DJBentley', 0)
# ('DJFoundation94', 0)
# ('DJJOEYMOJO', 0)
# ('DJMOS', 0)
# ('DJMany', 0)
# ('DJPatriotinCO', 0)
# ('DJPie', 0)
# ('DJSarahJane', 0)
# ('DJ_Johnny_Rich', 0)
# ('DJohnsonPGA', 0)
# ('DLaPCNN', 0)
# ('DLeone54', 0)
# ('DLoesch', 0)
# ('DMKGolfDesign', 0)
# ('DMcDonnell1', 0)
# ('DMcRorie', 0)
# ('DMehlo', 0)
# ('DOCnation_7', 0)
# ('DPJHodges', 0)
# ('DPaulMonteiro', 0)
# ('DPo8', 0)
# ('DREAMS_ACF', 0)
# ('DREDD001', 0)
# ('DREWMACsays', 0)
# ('DRINKtrimino', 0)
# ('DRJAMESCABOT', 0)
# ('DRSthefirst', 0)
# ('DRUDGE', 0)
# ('DRUDGE_REPORT', 0)
# ('DRepubblicait', 0)
# ('DSJR1', 0)
# ('DSchutzenhofer', 0)
# ('DShulman_ESPN', 0)
# ('DSpraguePGA', 0)
# ('DTSgolf', 0)
# ('DTSummerlin', 0)
# ('DTT_Golf', 0)
# ('DUittenbogaard', 0)
# ('DVEMike', 0)
# ('DVNJr', 0)
# ('DWXXIII', 0)
# ('DWilkins21', 0)
# ('DWilkinsonCNN', 0)
# ('DYWAyrshire', 0)
# ('DYWGlasgow', 0)
# ('D_Bell2', 0)
# ('D_Polichick', 0)
# ('DaRealAmberRose', 0)
# ('Dacre100', 0)
# ('DafnaLinzer', 0)
# ('DafnaMizrahi', 0)
# ('DailyBreezeNews', 0)
# ('DailyCaller', 0)
# ('DailyCutVideo', 0)
# ('DailyDilbert', 0)
# ('DailyLoveScopes', 0)
# ('DailyWorth', 0)
# ('DaintyGirl_TO', 0)
# ('DaisyBCreations', 0)
# ('DaisySociety', 0)
# ('DalaiLama', 0)
# ('DallasCharge', 0)
# ('DallasDirtCandy', 0)
# ('DallasPD', 0)
# ('DalmaAuciello', 0)
# ('Dalser58', 0)
# ('Dame_Lillard', 0)
# ('DamienFahey', 0)
# ('DamienSharkov', 0)
# ('Dammiann__', 0)
# ('DamnDaniel', 0)
# ('DamonforMayor', 0)
# ('DanBilefsky', 0)
# ('DanBilzerian', 0)
# ('DanCaporale', 0)
# ('DanClark17', 0)
# ('DanGrazianoESPN', 0)
# ('DanHauserGolf', 0)
# ('DanHicksNBC', 0)
# ('DanMaduri', 0)
# ('DanMarino', 0)
# ('DanMartin_Post', 0)
# ('DanMurphyGolf', 0)
# ('DanPatrick', 0)
# ('DanRather', 0)
# ('DanScavino', 220)
# ('Dan_DeLuca_Pro', 0)
# ('DanaBashCNN', 0)
# ('DanaFarberYAP', 0)
# ('DanaPerino', 0)
# ('Dance10Brittany', 0)
# ('Dance10Hayley', 0)
# ('DaneCook', 0)
# ('Danelle_dag', 0)
# ('Dangerfield__', 0)
# ('Dangolfer1', 0)
# ('DaniGor', 0)
# ('DaniaJaradat', 0)
# ('DanielBerger59', 0)
# ('DanielBoulud', 0)
# ('DanielLarison', 0)
# ('DanielMiernicki', 0)
# ('DanielSugrue', 0)
# ('DanielasWish', 0)
# ('DaniellaLSilva', 0)
# ('DaniellaMicaela', 0)
# ('DanielleBu95', 0)
# ('DanielleMonaro', 0)
# ('DanielleeDoty', 0)
# ('DaniloAmorepace', 0)
# ('DanniellaBrooks', 0)
# ('DannyDeVito', 0)
# ('DannyEFreeman', 0)
# ('DannyZuker', 0)
# ('Danny_Rixton', 0)
# ('Danny_Willett', 0)
# ('DansReview', 0)
# ('Dante_Antonini', 0)
# ('DantonioMark', 0)
# ('DardyYT', 0)
# ('DariAlexander', 0)
# ('DarkNetXX', 0)
# ('Darlene4NY', 0)
# ('DarrellKestner', 0)
# ('DarrellWard1983', 0)
# ('DarrenClarke60', 0)
# ('DarrenDreger', 0)
# ('DarrenJJordan', 0)
# ('DarrenPSMsports', 0)
# ('DarrenWalton369', 0)
# ('Darren_Williams', 0)
# ('Darren_howudoin', 0)
# ('Darth_Monty', 0)
# ('DarylJohnston', 0)
# ('DarylNuss', 0)
# ('Daryl_Manuel', 0)
# ('DashCamTwats', 0)
# ('DassaultFalcon', 0)
# ('DatelineNBC', 0)
# ('Dave4FtMyers', 0)
# ('DaveBratVA7th', 0)
# ('DaveEanet', 0)
# ('DaveFosterTips', 0)
# ('DaveLynndawg', 0)
# ('DaveMustaine', 0)
# ('DaveRyno12', 0)
# ('DaveShedloski', 0)
# ('DaveSheinin', 0)
# ('DaveValleMLB', 0)
# ('DaveWanta', 0)
# ('DaveWinfieldHOF', 0)
# ('DaveedDiggs', 0)
# ('DaveyMurray', 0)
# ('DavidAsmanfox', 0)
# ('DavidBLevin2', 0)
# ('DavidBurkeCBC', 0)
# ('DavidCMerrill', 0)
# ('DavidChalian', 0)
# ('DavidConnorGolf', 0)
# ('DavidEspoAP', 0)
# ('DavidFerrer87', 0)
# ('DavidGoodjohn', 0)
# ('DavidGrafboxing', 0)
# ('DavidJCaldwell', 0)
# ('DavidLeadbetter', 0)
# ('DavidLimbaugh', 0)
# ('DavidLloydESPN', 0)
# ('DavidLuiz_4', 0)
# ('DavidMGolf', 0)
# ('DavidMLatt', 0)
# ('DavidMarkDC', 0)
# ('DavidMillerSA12', 0)
# ('DavidMurrayPGA', 0)
# ('DavidNew72', 0)
# ('DavidPerez728', 0)
# ('DavidRoads', 0)
# ('DavidSilverOak', 0)
# ('DavidSpade', 0)
# ('DavidWalshST', 0)
# ('DavidWright_CNN', 0)
# ('David_Bossie', 0)
# ('David_Gergen', 0)
# ('David_Goldberg', 0)
# ('Davidiberg', 0)
# ('DavinHarpe', 0)
# ('DawnMannix', 0)
# ('DaxCabrera', 0)
# ('DaySpaAssoc', 0)
# ('DaynaSpringett', 0)
# ('Dazed', 0)
# ('Dcorrigan50', 0)
# ('De11eDonne', 0)
# ('De6rasse', 0)
# ('DeAndreWatts0', 0)
# ('DeAngeloRB', 0)
# ('DeLanaHarvick', 0)
# ('DeMar_DeRozan', 0)
# ('Deadline', 0)
# ('DeanAndDeLuca', 0)
# ('DeanDeLucaInv', 0)
# ('Deanofcomedy', 0)
# ('Deborah_Cox', 0)
# ('Decanter', 0)
# ('DecemberClassic', 0)
# ('DeeconX', 0)
# ('Deelaney31', 0)
# ('DeepakChopra', 0)
# ('Deer_Valley', 0)
# ('DeereDealer', 0)
# ('DeesideWater', 0)
# ('DefendingtheUSA', 0)
# ('DefenseIntel', 0)
# ('DefenseOne', 0)
# ('DefiFootball', 0)
# ('DegreeMen', 0)
# ('DeionSanders', 0)
# ('DeirdreBolton', 0)
# ('DelReyLatest', 0)
# ('DelenGoldberg', 0)
# ('Deli_Sandwiches', 0)
# ('DeliaDAmbraTV', 0)
# ('DeliveryPtGolf', 0)
# ('Dell', 0)
# ('DellMatchPlay', 0)
# ('Delta', 0)
# ('DeltaAssist', 0)
# ('Delton3030', 0)
# ('DempsterMartin', 0)
# ('Denali_Beth', 0)
# ('DeniseBidot', 0)
# ('DeniseLockwood', 0)
# ('DenisonSports', 0)
# ('DennisBasso', 0)
# ('DennisDMZ', 0)
# ('DennisHouseWFSB', 0)
# ('DennisSalesGolf', 0)
# ('DeptofDefense', 0)
# ('DerekBlasberg', 0)
# ('DerekErnst7', 0)
# ('DerekLamNYC', 0)
# ('DerekStoy', 0)
# ('Derek_Bard', 0)
# ('DermonttiDawson', 0)
# ('DermotByrne3', 0)
# ('DerryJournalPro', 0)
# ('DerryLiveList', 0)
# ('DerwinLGray', 0)
# ('DesertGolfGuy', 0)
# ('DesiPerkins', 0)
# ('Desigual_USA', 0)
# ('Dest_golfguide', 0)
# ('DestinationCAN', 0)
# ('DestinationIDo', 0)
# ('DetroitRedWings', 0)
# ('Dev34Harris', 0)
# ('Dev_Still71', 0)
# ('DevinDSays', 0)
# ('Devonte_Riley', 0)
# ('DiDougherty1', 0)
# ('DiZMAJiZ', 0)
# ('DiamondGray01', 0)
# ('DiamondandSilk', 240)
# ('DiamondsRunique', 0)
# ('DianaGould', 0)
# ('DianaLunaOdB', 0)
# ('DianaTaurasi', 0)
# ('DianeDonald', 0)
# ('DianeSawyer', 0)
# ('DickArmey', 0)
# ('DickieV', 0)
# ('DidiG18', 0)
# ('DiegoBernalTX', 0)
# ('DieuxDon', 0)
# ('DimitriosKPhoto', 0)
# ('DineshDSouza', 0)
# ('DingoCurl', 0)
# ('Dinoraorozco15', 0)
# ('DioniTabbers', 0)
# ('Dior', 0)
# ('DirtyFootbaIIer', 0)
# ('DismalRiver', 0)
# ('Disney', 0)
# ('Disney_Bride', 0)
# ('DividendMaster', 0)
# ('DjokerNole', 0)
# ('DlSurrette', 0)
# ('Dmccarthygolf', 0)
# ('Dnald_Trump2016', 0)
# ('DoYouLikeWine', 0)
# ('DocGooden16', 0)
# ('DocODU', 0)
# ('DoctorDimbleton', 0)
# ('DodgersPR', 0)
# ('DodoJewels', 0)
# ('DodoMolinari', 0)
# ('DoloresHuerta', 0)
# ('DomRacine', 0)
# ('Dom_Fitzhugh', 0)
# ('DonCheadle', 0)
# ('DonLagreca', 0)
# ('DonRickles', 0)
# ('DonYaeger', 0)
# ('DonaldJTrumpJr', 120)
# ('DonaldTrumpNH', 0)
# ('DonaldTrumpNet', 0)
# ('DonaldTrumpVote', 0)
# ('Donald_Driver80', 0)
# ('DonnaBen1', 0)
# ('DonnaL011', 0)
# ('DonnaOrender', 0)
# ('DonnellyJoie', 0)
# ('Dottie_Pepper', 0)
# ('DoubleDutchMix', 0)
# ('DougClerget', 0)
# ('DougFeinberg', 0)
# ('DougFlutie', 0)
# ('DougLuzader', 0)
# ('DouglasElliman', 0)
# ('DouglasHPhoto', 0)
# ('Douglas_Main', 0)
# ('DougsATM', 0)
# ('Downey_AOR', 0)
# ('DowntownCLE', 0)
# ('DowntownDCBID', 0)
# ('DoxDocherty', 0)
# ('DpiDesignUK', 0)
# ('Dpugh54', 0)
# ('DrAllmen', 0)
# ('DrBronner', 0)
# ('DrFNFurter', 0)
# ('DrJMieres', 0)
# ('DrJamesDManning', 0)
# ('DrKanbalhi', 0)
# ('DrLHazzouri', 0)
# ('DrLMelchor', 0)
# ('DrNancySimpkins', 0)
# ('DrNickGolf', 0)
# ('DrNinaRadcliff', 0)
# ('DrOz', 0)
# ('DrPatSoonShiong', 0)
# ('DrPetey15', 0)
# ('DrSallyAndrews', 0)
# ('DrScienceCat', 0)
# ('DrShefali', 0)
# ('DrTurfBug', 0)
# ('DrWeil', 0)
# ('DrZuhdiJasser', 0)
# ('Dr_Dirt2000', 0)
# ('DraftKings', 0)
# ('Drake', 0)
# ('DrawPlayDave', 0)
# ('DreamTravelMag', 0)
# ('DreamlandGCBaku', 0)
# ('DreddyTennis', 0)
# ('DrewBlahBlah', 0)
# ('DrewBledsoe', 0)
# ('DrewGriffinCNN', 0)
# ('DrewHampshire', 0)
# ('Drive495', 0)
# ('DriveChipPutt', 0)
# ('DrncPno', 0)
# ('DrudgeBuzz', 0)
# ('DryjectNJ', 0)
# ('DsonRedDevils', 0)
# ('DuJourMedia', 0)
# ('DucciAssociates', 0)
# ('DuceBaily', 0)
# ('DuckInnChicago', 0)
# ('DuckyCarlie', 0)
# ('DukeCastiglione', 0)
# ('Duke_MBB', 0)
# ('Duke_WGOLF', 0)
# ('Dukes9797', 0)
# ('Dumfries_House', 0)
# ('DunnItAlready25', 0)
# ('DunningGolf', 40)
# ('Dusenberry_Golf', 0)
# ('Duskin_Stephens', 0)
# ('DustinBrown23', 0)
# ('DustinFox37', 0)
# ('DutchessGolf', 0)
# ('Duxdro', 0)
# ('DwyaneWade', 0)
# ('DylanByers', 0)
# ('DylanDreyerNBC', 0)
# ('Dylanlarkin39', 0)
# ('DylansCandyBar', 0)
# ('DynamicFandS', 0)
# ('E3', 0)
# ('EA_Stripes', 0)
# ('ECPmarkwilson', 0)
# ('EDIE_PARKER', 0)
# ('EDS1NGLETON', 0)
# ('EFowlerFGCUPGM', 0)
# ('EGrace', 0)
# ('EHolmesWSJ', 0)
# ('EJUpClose', 0)
# ('ELLEMagUK', 0)
# ('ELLEMalaysia', 0)
# ('ELLEUK', 0)
# ('ELLEmagazine', 0)
# ('EMichaelGW', 0)
# ('EPN', 0)
# ('EP_President', 0)
# ('ESPN3', 0)
# ('ESPNArgentina', 0)
# ('ESPNBookers', 0)
# ('ESPNCFB', 0)
# ('ESPNCaddie', 0)
# ('ESPNCareers', 0)
# ('ESPNDatos', 0)
# ('ESPNDeportes', 0)
# ('ESPNDrLou', 0)
# ('ESPNF1', 0)
# ('ESPNFC', 0)
# ('ESPNFrontRow', 0)
# ('ESPNGolf', 0)
# ('ESPNInsider', 0)
# ('ESPNLunardi', 0)
# ('ESPNNASCAR', 0)
# ('ESPNNFL', 0)
# ('ESPNNY98_7FM', 0)
# ('ESPNOlympics', 0)
# ('ESPNPR', 0)
# ('ESPNResearch', 0)
# ('ESPNStatsInfo', 0)
# ('ESPNStreak', 0)
# ('ESPNTennis', 0)
# ('ESPNU', 0)
# ('ESPN_Cronometro', 0)
# ('ESPN_Endurance', 0)
# ('ESPN_FanCentral', 0)
# ('ESPN_RobKing', 0)
# ('ESPN_WomenHoop', 0)
# ('ESPYS', 0)
# ('ESQPolitics', 0)
# ('ESchattner', 0)
# ('ESparkGlobal', 0)
# ('ESqHospitality', 0)
# ('ETS_Corp', 0)
# ('EVENTSBYAMABLE', 0)
# ('EVSCSuper', 0)
# ('EW', 0)
# ('EWNsport', 0)
# ('EWagsterPettus', 0)
# ('EWhiteheadFdn', 0)
# ('EYTech', 0)
# ('EZGO_NJ', 0)
# ('E_Spencer6', 0)
# ('EamonJavers', 0)
# ('EamonnCoghlan1', 0)
# ('EarlDibblesJr', 0)
# ('EastHumble', 0)
# ('EasterbrookG', 0)
# ('EasternGolfClub', 0)
# ('EatFatRice', 0)
# ('EaterNY', 0)
# ('EaterVegas', 0)
# ('EatingMadeEasy', 0)
# ('EazyIB_17', 0)
# ('EboniKWilliams', 0)
# ('Ebyrne122', 0)
# ('Echmurak', 0)
# ('EconBizFin', 0)
# ('EconBritain', 0)
# ('EdBouchette', 0)
# ('EdWestwick', 0)
# ('Ed_Demaria', 0)
# ('Ed_Hardin', 0)
# ('EddWBrown', 0)
# ('Eddie_Schmidt', 0)
# ('EddyWarman', 0)
# ('Edelman11', 0)
# ('EdenEspinosa', 0)
# ('Edewalker', 0)
# ('EdeyoFoundation', 0)
# ('Edge4Prezident', 0)
# ('EdgewoodCountry', 0)
# ('Edible_Feast', 0)
# ('EdisonLearning', 0)
# ('EditorNicoleK', 0)
# ('Edufii', 0)
# ('EdvisoryCouncil', 0)
# ('EdwardGLuce', 0)
# ('Edward_Enninful', 0)
# ('Edwerderespn', 0)
# ('EgidioBOfficial', 0)
# ('Egoscue_PBG', 0)
# ('Ehasty200', 0)
# ('EinsteinMed', 0)
# ('EireBritainGolf', 0)
# ('Ekblad5FLA', 0)
# ('EkeKimmo', 0)
# ('ElBeardsley', 0)
# ('ElParaisoGolf', 0)
# ('El_Coffee', 0)
# ('EladRatson', 0)
# ('EleanorLangston', 0)
# ('ElectricSchneid', 0)
# ('ElenaNachmanoff', 0)
# ('ElenesKitchen', 0)
# ('EliBWatkins', 0)
# ('EliHMiller', 0)
# ('EliMainini', 0)
# ('EliasSports', 0)
# ('EliotShorrParks', 0)
# ('Elise_Jordan', 0)
# ('EliteCarServ', 0)
# ('EliteDaily', 0)
# ('EliteTravelerDG', 0)
# ('ElizLanders', 0)
# ('ElizaGoodnight', 0)
# ('ElizabethHeap', 0)
# ('ElizabethPrann', 0)
# ('ElizandJames', 0)
# ('ElizbethLManess', 0)
# ('ElkRiverClub', 0)
# ('Ella_LaPetite', 0)
# ('ElleHegarty8', 0)
# ('Ellen1945ekj', 0)
# ('EllenPage', 0)
# ('EllensRedChairs', 0)
# ('EllieSRocks', 0)
# ('EllingYelling', 0)
# ('ElmcrestClub', 0)
# ('ElmetsPR', 0)
# ('ElmoJRinaldi', 0)
# ('ElvisCostello', 0)
# ('ElvisDuranShow', 0)
# ('EmWatson', 0)
# ('EmbassySuites', 0)
# ('Emeril', 0)
# ('EmilyMiller', 0)
# ('Eminem', 0)
# ('EmmPagge', 0)
# ('EmmaGJones', 0)
# ('EmmaJactress', 0)
# ('EmmaODriscoll19', 0)
# ('Emmaleewalpole', 0)
# ('EmmettScanlan', 0)
# ('EmmittSmith22', 0)
# ('EmojiExploji', 0)
# ('EmpireCCasino', 0)
# ('EnGAYgedWedding', 0)
# ('EngageCleveland', 0)
# ('EnglandGolf', 0)
# ('Eno_Pinchiorri', 0)
# ('Enrique_Rojas1', 0)
# ('EntrePROapp', 0)
# ('Entrepreneur', 0)
# ('EntrepreneurQ', 0)
# ('Enviius', 0)
# ('EoinFitzgerald1', 0)
# ('Epic_Women', 0)
# ('EpsteinTravels', 0)
# ('EremenkoAlexey', 0)
# ('EricBana67', 0)
# ('EricBolling2', 0)
# ('EricPBme', 0)
# ('EricRClose', 0)
# ('EricRoberts', 0)
# ('EricThomasWBTV', 0)
# ('EricTrump', 340)
# ('EricTrumpFdn', 340)
# ('EricWynalda', 0)
# ('ErikCompton3', 60)
# ('ErikSherman', 0)
# ('ErikWemple', 0)
# ('Erik_M97', 0)
# ('ErikaLinder', 0)
# ('ErinAndrews', 40)
# ('ErinBurnett', 0)
# ('ErinFetherston', 0)
# ('ErinHillsGolf', 0)
# ('ErinSharoni', 0)
# ('Erin_Houchin', 0)
# ('ErwinBros', 0)
# ('EspinozaAnthon', 0)
# ('Espngreeny', 20)
# ('EssendonCCGolf', 0)
# ('EssexBridalTalk', 0)
# ('EstebanSolisTV', 0)
# ('EthanRitz', 0)
# ('EthanatorCG', 0)
# ('Etherkat', 0)
# ('EtonOldBoys', 0)
# ('EtownBlueJays', 0)
# ('Eugene_Scott', 0)
# ('EuroSeniorTour', 0)
# ('EuropeanTour', 0)
# ('EvaDelRey_', 0)
# ('EvaShockey', 0)
# ('EvanAntin', 0)
# ('EvanJKessler', 0)
# ('EvanWest1', 0)
# ('Evan_McMullin', 0)
# ('Evan_Schiller', 0)
# ('EvangelistKathl', 0)
# ('EvelynPintado', 0)
# ('EveningExpress', 0)
# ('EventPlannerNYC', 0)
# ('EveryBallCounts', 0)
# ('EverythingLibra', 0)
# ('EverythingNYC', 0)
# ('EvianChamp', 0)
# ('Evins', 0)
# ('EwanPat0n', 0)
# ('ExcelleKim', 0)
# ('ExcelleSports', 0)
# ('ExcuseThePuns_', 0)
# ('ExeGolfSociety', 0)
# ('ExecGolfLeisure', 0)
# ('ExecutivePour', 100)
# ('Expectamen23', 0)
# ('ExplorationHI', 0)
# ('ExploreCanada', 0)
# ('ExposureNY', 0)
# ('EyeOnFreedom', 0)
# ('EzekielElliott', 0)
# ('F3Honeymoon', 0)
# ('FAIRHealth', 0)
# ('FAOstatistics', 0)
# ('FCAthletics', 0)
# ('FCNewYork', 0)
# ('FCUK', 0)
# ('FCousteau', 0)
# ('FDNY', 0)
# ('FDNYMuseum', 0)
# ('FESbarro', 0)
# ('FFSGym', 0)
# ('FINOFile', 0)
# ('FIT28', 0)
# ('FLAGALine', 0)
# ('FLAGSofVALOR', 0)
# ('FLConserve941', 0)
# ('FLFreedivers', 0)
# ('FLGovScott', 0)
# ('FLOTUS', 0)
# ('FLongobardi', 0)
# ('FMCturf', 0)
# ('FM_LauraH', 0)
# ('FNCLowell', 0)
# ('FNReporting', 0)
# ('FOBIA_Leaders', 0)
# ('FOBRacing', 0)
# ('FOX19', 0)
# ('FOX2News', 0)
# ('FOX4', 0)
# ('FOX411Country', 0)
# ('FOX5Atlanta', 0)
# ('FOXBaltimore', 0)
# ('FOXSports', 0)
# ('FOXSportsU', 0)
# ('FOXTV', 0)
# ('FOXlightMichael', 0)
# ('FRANCE24', 0)
# ('FRCCAgronomy', 0)
# ('FRL126', 0)
# ('FS1', 0)
# ('FSKPart3', 0)
# ('FSU_Falcons', 0)
# ('FScandale', 0)
# ('FStubblefield3', 0)
# ('FT', 0)
# ('FTKong', 0)
# ('FTVLive', 0)
# ('FYLFoundation', 0)
# ('F_Molinari', 0)
# ('FabianGomezGolf', 0)
# ('FabianKoss', 0)
# ('Fabletics', 0)
# ('FactUP', 0)
# ('FactsGuide', 0)
# ('FahadAlhammad', 0)
# ('FahadDhimself', 0)
# ('FailuresOnTV', 0)
# ('FairFolks', 0)
# ('FairwayGreene', 0)
# ('FairwayToGolf', 0)
# ('FaithSoStrong', 0)
# ('FalconsDQ', 0)
# ('FallonTonight', 0)
# ('Fallon_Fitz', 0)
# ('Famousone2014', 0)
# ('Fannycaddie', 0)
# ('FareedZakaria', 0)
# ('FarrellEvans75', 0)
# ('Fascinatingpics', 0)
# ('FashionWeek', 0)
# ('Fashion_Exec', 0)
# ('Fashion_Monitor', 0)
# ('Fashionista_com', 0)
# ('FashionweekNYC', 0)
# ('FastCompany', 0)
# ('Fastnote', 0)
# ('FaverTim', 0)
# ('FavorIntl', 0)
# ('FazulRahimF', 0)
# ('FckWhatYouHeard', 0)
# ('Fdarbs', 0)
# ('FedUpAmerican5', 0)
# ('FederalDonuts', 0)
# ('FeedINsHungry', 0)
# ('Fehertwit', 0)
# ('FeinbergFOX5', 0)
# ('Femme_Foodie', 0)
# ('Fendi', 0)
# ('Fergie', 0)
# ('Fetskostack', 0)
# ('Fiedler', 0)
# ('FieldRoamer', 0)
# ('FieldYates', 0)
# ('FieldsportsMag', 0)
# ('Fiery01Red', 0)
# ('FifitFiona', 0)
# ('Fight2dream', 0)
# ('FiletMannion', 0)
# ('FilsonAndrew', 0)
# ('FinancialReview', 0)
# ('FinnegansNY', 0)
# ('FionaZanetti', 0)
# ('FirstFridayLV', 0)
# ('FirstNationwide', 0)
# ('FiscalizadorPTY', 0)
# ('Fishr', 0)
# ('Fiskee60', 0)
# ('FitspirationaI', 0)
# ('FiveThirtyEight', 0)
# ('FlaPanthers', 0)
# ('FlattyPGA', 0)
# ('FlavaFraz21', 0)
# ('FlemmingDave', 0)
# ('FleurDeForce', 0)
# ('FlexAforeal', 0)
# ('Flexjet', 0)
# ('FlightScopeGolf', 0)
# ('FlintNow', 0)
# ('FlipMyTie', 0)
# ('Flipboard', 0)
# ('FlorianOrth', 0)
# ('FloridaGOP', 0)
# ('FloridaHospital', 0)
# ('FlyKebo', 0)
# ('FlyingMonkeys4U', 0)
# ('Flying_Bunna', 0)
# ('FocusGolfGroup', 0)
# ('FocusonCancer', 0)
# ('FoldsofHonor', 0)
# ('Follow24Hodge', 0)
# ('FollowMMA', 0)
# ('Followtheblonde', 0)
# ('FooFightersDave', 0)
# ('Fooch1993', 0)
# ('FoodFest15', 0)
# ('FoodFlicker', 0)
# ('FoodNetwork', 0)
# ('FoodStringer', 0)
# ('FoodTravelChat', 0)
# ('Fooditor', 0)
# ('FoolishThoughtz', 0)
# ('FootJoy', 0)
# ('FootbaIITwats', 0)
# ('FootyAwayDays_', 0)
# ('FootyFIashbacks', 0)
# ('FootyFansChants', 0)
# ('ForAmerica', 0)
# ('ForTheWin', 0)
# ('Forbes', 0)
# ('ForbesInspector', 0)
# ('ForbesLife', 0)
# ('ForbesVideo', 0)
# ('FordOConnell', 0)
# ('FordyceJamie', 0)
# ('Foregolfcustom', 0)
# ('ForestHighlands', 0)
# ('FormartineUtdYA', 0)
# ('Formartines', 0)
# ('FormentosChi', 0)
# ('ForsgateGolfDpt', 0)
# ('FortuneMagazine', 0)
# ('FortunePartners', 0)
# ('FourSeasons', 0)
# ('FoxBusiness', 100)
# ('FoxBusinessAM', 0)
# ('FoxFriendsFirst', 0)
# ('FoxNews', 20)
# ('FoxNewsCommie', 0)
# ('FoxNewsInsider', 0)
# ('FoxNewsLive', 0)
# ('FoxNewsPhotos', 0)
# ('FoxNewsResearch', 0)
# ('FoxNewsSunday', 0)
# ('Foxworth24', 0)
# ('FrLouisVuitton', 0)
# ('FrancesRobles', 0)
# ('FrancescaFox_', 0)
# ('FranchiseABC123', 0)
# ('FrankBruni', 0)
# ('FrankCaliendo', 0)
# ('FrankDarby3', 0)
# ('FrankNobiloGC', 40)
# ('FrankSunTimes', 0)
# ('FrankieColetto', 0)
# ('Franklin_Graham', 0)
# ('Franschhoek_SA', 0)
# ('Frat_Ryan', 0)
# ('FravelTravel', 0)
# ('FredBThird', 0)
# ('FredGriffinGolf', 0)
# ('FredMonyak', 0)
# ('FredVR_', 0)
# ('FredYelverton', 0)
# ('FreddieJac', 0)
# ('FreddieMac_FBG', 0)
# ('FreddyMelendez', 0)
# ('Frederica_puls', 0)
# ('FredericksburgH', 0)
# ('FredicasF', 0)
# ('FredrikEklundNY', 0)
# ('FreeDerryjour', 0)
# ('FreeYourGolf', 0)
# ('FreedomHouseDC', 0)
# ('FreeformTV', 0)
# ('FreshGolfRev', 0)
# ('FridaKahlo76', 0)
# ('FriendJeff', 0)
# ('FrndofafrndNY', 0)
# ('Frommers', 0)
# ('FroschTravel', 0)
# ('Frostpga', 0)
# ('FrugalTravelGuy', 0)
# ('FullMeasureNews', 0)
# ('FultonGinger', 0)
# ('Funi_02', 0)
# ('Furthermore', 0)
# ('Fusion', 0)
# ('FutoButaRamen', 0)
# ('G4girl18', 0)
# ('GAMEGOLF', 0)
# ('GAofPhilly', 0)
# ('GBK_Productions', 0)
# ('GBRSportingClub', 0)
# ('GBrowneMarshall', 0)
# ('GC3greg', 0)
# ('GCA', 0)
# ('GCGA', 0)
# ('GCHermieTracker', 0)
# ('GCImagazine', 0)
# ('GCM_Magazine', 0)
# ('GCMorningDrive', 0)
# ('GCPDIndiana', 0)
# ('GCSAA', 0)
# ('GCSANJ1926', 0)
# ('GCTigerTracker', 0)
# ('GD_MikeO', 0)
# ('GDemo', 0)
# ('GGCAgronomy', 0)
# ('GHughes51', 0)
# ('GIAMMETTI', 0)
# ('GJSmudger', 0)
# ('GLWOODPHOTO', 0)
# ('GMA', 0)
# ('GMFincaCortesin', 0)
# ('GMJeanLucBarone', 0)
# ('GMPent', 0)
# ('GMac_Apparel', 0)
# ('GMatTRUMPNY', 0)
# ('GOLD_555_MR', 0)
# ('GOLFFOODADDICT', 0)
# ('GOLFenESPN', 0)
# ('GOLFonCBS', 60)
# ('GOLFstats', 0)
# ('GOMADandMONSTER', 0)
# ...
# ('serafinowicz', 0)
# ('serenaamarronn', 0)
# ('serenawilliams', 0)
# ('set_susanturner', 0)
# ('sethedel', 0)
# ('sethmeyers', 0)
# ('sevenpetes77', 0)
# ('seventhandwit', 0)
# ('sewrighter', 0)
# ('sgiraltbmtdoc', 0)
# ('sgmc_to', 0)
# ('sgross1983', 0)
# ('sgtw2016', 0)
# ('shab_87', 0)
# ('shailgulhati', 0)
# ('shamar_walters', 0)
# ('shamarimaurice', 0)
# ('shane_stewart11', 0)
# ('shanebacon', 0)
# ('shanesmith30', 0)
# ('shanewrightcgcs', 0)
# ('shannabright', 0)
# ('shannonNTIL', 0)
# ('shannonjpoole', 0)
# ('shanshanfengCHN', 0)
# ('shappy730', 0)
# ('shaqbrewster', 0)
# ('shaqtin', 0)
# ('sharpergolf', 0)
# ('shaunagh', 0)
# ('shaungoodman', 0)
# ('shauntomson', 0)
# ('shawnstern', 0)
# ('shegotgame', 0)
# ('sheispaloma', 0)
# ('shelby_douglas', 0)
# ('shellbatts', 0)
# ('sherao', 0)
# ('sheryllecalder', 0)
# ('shestokas', 0)
# ('sheswanderful', 0)
# ('shezamodel', 0)
# ('shgaymitchell', 0)
# ('shitmydadsays', 0)
# ('shojinator', 0)
# ('shopbop', 0)
# ('shoptheupside', 0)
# ('showbams', 0)
# ('shwnsgf', 0)
# ('si_golf', 0)
# ('si_olympics', 0)
# ('si_tratta_charl', 0)
# ('sianwatson', 0)
# ('sidzven', 0)
# ('sierrapal', 0)
# ('signsbytheseaNJ', 0)
# ('silkwaytravel', 0)
# ('silverjeansco', 0)
# ('simihaze', 0)
# ('simonhansongolf', 0)
# ('simonmainwaring', 0)
# ('simons', 0)
# ('simonschuster', 0)
# ('simplymeasured', 0)
# ('singerblinger', 0)
# ('sipgrinder', 0)
# ('siplaysports', 0)
# ('sipwsocialites', 0)
# ('sirencommspr', 0)
# ('siriusxmu', 0)
# ('sistertoldjah', 0)
# ('sivgreyson', 0)
# ('sjoman_jacob', 0)
# ('skilletmusic', 0)
# ('skillsdevscot', 0)
# ('sky_cowans', 0)
# ('skyferreira', 0)
# ('skyhighshoot', 0)
# ('skyphoto', 0)
# ('skysportnz', 0)
# ('sleavitt00', 0)
# ('slima2z', 0)
# ('slingfish', 0)
# ('slone', 0)
# ('slprimefoodtrck', 0)
# ('smadaj', 0)
# ('smahal1', 0)
# ('smanskar', 0)
# ('smartflyerrob', 0)
# ('smhmario', 0)
# ('smilin83', 0)
# ('smorgasburg', 0)
# ('smuckers', 0)
# ('smyles', 0)
# ('sncathletics', 0)
# ('snowman2469', 0)
# ('so3projects', 0)
# ('socalinvestor', 0)
# ('socialtables', 0)
# ('sofiaguellaty', 0)
# ('sofiargross', 0)
# ('sohoandnoho1', 0)
# ('soledadobrien', 0)
# ('solidgolf', 0)
# ('solotraveler', 0)
# ('somekindasport', 0)
# ('soniarykiel', 0)
# ('sonskyn66', 0)
# ('sophia_bruner', 0)
# ('sophiaamoruso', 0)
# ('sophialfish', 0)
# ('sophibraz', 0)
# ('sophie_tatum', 0)
# ('sophiepowell91', 0)
# ('sophierosebell1', 0)
# ('sophieturner1', 0)
# ('sorelfootwear', 0)
# ('sorryimalex', 0)
# ('soulcycle', 0)
# ('souljazzfunk', 0)
# ('source24designs', 0)
# ('spasofamerica', 0)
# ('spectrumtech', 0)
# ('speedgolfrob', 0)
# ('speedracer38', 0)
# ('spencerpratt', 0)
# ('spike', 0)
# ('sportsandchange', 0)
# ('sportsemmys', 0)
# ('sportsfile', 0)
# ('sportsiren', 0)
# ('sportspickle', 0)
# ('sportsreiter', 0)
# ('sportsstudfool', 0)
# ('sportzwerg', 0)
# ('spring', 0)
# ('springmillsol', 0)
# ('spudsnine', 0)
# ('srwestin', 0)
# ('sryan03', 0)
# ('sshall4', 0)
# ('ssi921', 0)
# ('sspgolf', 0)
# ('sssourabh', 0)
# ('ssteeeeef', 0)
# ('stabenow', 0)
# ('stacie_mitchell', 0)
# ('stacy_wright_', 0)
# ('stacyannj', 0)
# ('stacylondon', 0)
# ('stallingsgolf', 0)
# ('stanburnwine', 0)
# ('stanverrett', 0)
# ('star_system', 0)
# ('starke_will', 0)
# ('startelegram', 0)
# ('stasiahardin', 0)
# ('statedeptspox', 0)
# ('stavziv', 0)
# ('stayeventsuk', 0)
# ('stdavids1897', 0)
# ('steelers', 0)
# ('stef_mitchell', 0)
# ('steparry2', 0)
# ('stephanieakling', 0)
# ('stephannesmith', 0)
# ('stephen52814897', 0)
# ('stephen_bow', 0)
# ('stephen_pga', 0)
# ('stephenasmith', 0)
# ('stephencbishop', 0)
# ('stephenfhayes', 0)
# ('stephne78', 0)
# ('stephscm', 0)
# ('sternshow', 0)
# ('stevebeuerlein', 0)
# ('stevecuozzo', 0)
# ('stevejpga', 0)
# ('stevenmcc82', 0)
# ('stevenwhiteside', 0)
# ('stevepriest', 0)
# ('stevespriester', 0)
# ('stevestricker', 0)
# ('stewartcink', 0)
# ('stivescc_vcsup', 0)
# ('stivesgolfclub', 0)
# ('stlappas', 0)
# ('stlcountypd', 0)
# ('stonrgrlproblem', 0)
# ('stoolpresidente', 0)
# ('stopdk12', 0)
# ('stoutard', 0)
# ('stoutbluedevils', 0)
# ('stranahan', 0)
# ('strangthngs', 0)
# ('stratism', 0)
# ('streeteasy', 0)
# ('striturf_richw', 0)
# ('stuartpstevens', 0)
# ('sturtze56', 0)
# ('stuttle10', 0)
# ('styleonscreen', 0)
# ('subirchowdhury', 0)
# ('successmagazine', 0)
# ('suecofarrell', 0)
# ('suemack8', 0)
# ('sunny', 0)
# ('suohgolf', 0)
# ('supaflymo', 0)
# ('super_novo', 0)
# ('superstitionmtn', 0)
# ('supinncgolfccc', 0)
# ('supkayc', 0)
# ('susancandiotti', 0)
# ('susanshin7', 0)
# ('susie_dent', 0)
# ('suzannpettersen', 0)
# ('suzywhaley', 0)
# ('swebs', 0)
# ('sweep1984', 0)
# ('sweetloloflu', 0)
# ('swheeler28', 0)
# ('swils29', 0)
# ('swimmacc', 0)
# ('swingOIL', 0)
# ('swingbyte', 0)
# ('sydney_destin', 0)
# ('sydneyleroux', 0)
# ('sylviarestate', 0)
# ('synjenherren', 0)
# ('t_masahiro18', 0)
# ('tabacoffd', 0)
# ('tabby_e', 0)
# ('tafrank', 0)
# ('talentdotgolf', 0)
# ('talley_emma', 0)
# ('talyellin', 0)
# ('talymakeup', 0)
# ('tammimmurphy', 0)
# ('tammyhandler', 0)
# ('tangodancer208', 0)
# ('tanyagorton72', 0)
# ('tanzinavega', 0)
# ('taolasvegas', 0)
# ('taralipinski', 0)
# ('tarbel', 0)
# ('tartanathletics', 0)
# ('tatianaplatt', 0)
# ('taulukos', 0)
# ('taycarlyjenner', 0)
# ('taylorcarlier', 0)
# ('tayloreigsti', 0)
# ('taylorswift13', 0)
# ('tayshabrinson', 0)
# ('tbear582', 0)
# ('tbloom_SPCC', 0)
# ('tbozz1174', 0)
# ('tbridis', 0)
# ('tcgillis', 0)
# ('tcolmocallaghan', 0)
# ('tcurley11', 0)
# ('tdemiguel_AP', 0)
# ('tdixon20', 0)
# ('tealtoes', 0)
# ('team_FIP', 0)
# ('teamlebron', 0)
# ('teamstream', 0)
# ('teatimetayla', 0)
# ('techreview', 0)
# ('tedbishop38pga', 120)
# ('tedcruz', 0)
# ('teddymargules', 0)
# ('teddyschleifer', 0)
# ('tedgibson', 0)
# ('tedjarrett', 0)
# ('tedligety', 0)
# ('teeofftimes_CS', 0)
# ('teeofftimes_DR', 0)
# ('teeofftimes_FC', 0)
# ('teeofftimes_ck', 0)
# ('tejasrunnergirl', 0)
# ('templemarston', 0)
# ('tenthavenorth', 0)
# ('terracastro', 0)
# ('terrellowens', 0)
# ('terryporter30', 0)
# ('terryscollins', 0)
# ('tessasanderson', 0)
# ('texasgolfergirl', 0)
# ('textistentially', 0)
# ('tgmozz1', 0)
# ('tgoet', 0)
# ('thahoneyB', 0)
# ('thakoon', 0)
# ('thalia', 0)
# ('thatjongoldman', 0)
# ('thatshitgray26', 0)
# ('thatton91', 0)
# ('theBeutlerdidit', 0)
# ('theCHIVE', 0)
# ('theCarlaMarie', 0)
# ('theConSoulTant', 0)
# ('theDHB85', 0)
# ('theDominatorCFS', 0)
# ('theFareoh', 0)
# ('theJSKang', 0)
# ('theMMQB', 0)
# ('theNYPC', 0)
# ('theRubinReview', 0)
# ('theSmartFlyer', 0)
# ('the_BFJ', 0)
# ('the_fried_egg', 0)
# ('theaglab', 0)
# ('thealinacho', 0)
# ('theashleygraham', 0)
# ('theaudience', 0)
# ('theautumn_b', 0)
# ('thebingblog', 0)
# ('theblackestdays', 0)
# ('theblackkeys', 0)
# ('theblaze', 0)
# ('thebrunchboxct', 0)
# ('thechatwalny', 0)
# ('thechedderman', 0)
# ('thechicagolite', 0)
# ('thecitiboi', 0)
# ('thecobrasnake', 0)
# ('thecoliny', 0)
# ('thecoveteur', 0)
# ('thedailybeast', 0)
# ('thedapifer', 0)
# ('thedianaeastman', 0)
# ('thedrive', 0)
# ('thefabdirector', 0)
# ('theferocity', 0)
# ('thefisherbee', 0)
# ('thefoodjunky', 0)
# ('theforum', 0)
# ('theforwardtees', 0)
# ('thegarance', 0)
# ('thegolfblog', 0)
# ('thegolfclubgame', 0)
# ('thehenebrys', 0)
# ('theheraldsun', 0)
# ('thehill', 0)
# ('thehoosiergym', 0)
# ('thehuffpost_', 0)
# ('thehunt', 0)
# ('thehuve', 0)
# ('thejackhuston', 0)
# ('thejkstudio', 0)
# ('thejohnsalley', 0)
# ('thejointstaff', 0)
# ('thejoshaltman', 0)
# ('thejoshpatten', 0)
# ('thekatbrooks', 0)
# ('thekellyford', 0)
# ('thekidmcmanus', 0)
# ('thekomedyplace', 0)
# ('thelocalwedding', 0)
# ('themanda3', 0)
# ('themarcjacobs', 0)
# ('themarcliffe', 0)
# ('themichellewie', 0)
# ('themisswhisky', 0)
# ('themuzza60', 0)
# ('thenation', 0)
# ('thenextmiami', 0)
# ('theodenjanes', 0)
# ('theoduscrane', 0)
# ('theoliverhudson', 0)
# ('theparkvegas', 0)
# ('thepennyhoarder', 0)
# ('thephamradio', 0)
# ('thephilwills', 0)
# ('theplanetd', 0)
# ('thepointsguy', 0)
# ('thequote', 0)
# ('thereaIbanksy', 0)
# ('therealGFD', 0)
# ('therealcamargo', 0)
# ('therealcornett', 0)
# ('therealgokwan', 0)
# ('therealmarymary', 0)
# ('therealstrebber', 0)
# ('thereecegrover', 0)
# ('theremdog', 0)
# ('theresa_may', 0)
# ('therightnewz', 0)
# ('thesarahrose', 0)
# ('theskimm', 0)
# ('thesmitty15', 0)
# ('thetblogger', 0)
# ('thethrill57', 0)
# ('thetigofficial', 0)
# ('thetimes', 0)
# ('thetimothydrake', 0)
# ('thetracyaustin', 0)
# ('thetracymoore', 0)
# ('theturfyoda', 0)
# ('thetwintraveler', 0)
# ('theweeknd', 0)
# ('thewestlakemag', 0)
# ('thewongone', 0)
# ('theycallmeMOSH', 40)
# ('theyknowSims_', 0)
# ('thiam_nafi', 0)
# ('thibautcourtois', 0)
# ('thinkingnomads', 0)
# ('thomasbjorngolf', 0)
# ('thomasgmorris1', 0)
# ('thomaslake', 0)
# ('thomaslevetgolf', 0)
# ('threeASFOUR', 0)
# ('threeguysgolf', 0)
# ('thruthelinks', 0)
# ('tiffanytunes', 0)
# ('tifosioptics', 0)
# ('tim_cook', 0)
# ('timestravel', 0)
# ('timgrohmann', 0)
# ('timguinn', 0)
# ('timkaine', 0)
# ('timpappas1', 0)
# ('timyelverton', 0)
# ('tinamayers', 0)
# ('tipofmytongue06', 0)
# ('tiqobev', 0)
# ('tisroodentweet', 0)
# ('titoortiz', 0)
# ('tj03howe', 0)
# ('tjhuddle', 0)
# ('tjmartell', 0)
# ('tjumpjenny', 0)
# ('tkcuisine', 0)
# ('tlheard12', 0)
# ('tlhpro', 0)
# ('tluathletics', 0)
# ('tmagazine', 0)
# ('tmansutter', 0)
# ('tmills15', 0)
# ('tmoorewps', 0)
# ('tnuomycart', 0)
# ('tob_da', 0)
# ('toddbud', 0)
# ('toddstarnes', 0)
# ('tokamid', 0)
# ('tombermanap', 0)
# ('tombrokaw', 0)
# ('tomclark21', 0)
# ('tomcunneff', 0)
# ('tomdetry', 0)
# ('tomdreesencomic', 0)
# ('tomhaberstroh', 0)
# ('tomhanks', 0)
# ('tomhawkins_', 0)
# ('tomhoffarth', 0)
# ('tomlobianco', 0)
# ('tommargetts', 0)
# ('tommybarnett', 0)
# ('tommykato', 0)
# ('tommylimbaugh', 0)
# ('tommyxtopher', 0)
# ('tomshillue', 0)
# ('tomsniko', 0)
# ('tomstickneygolf', 0)
# ('tony_sheffler', 0)
# ('tonyamccallgolf', 0)
# ('tonyamharper', 0)
# ('tonydokoupil', 0)
# ('tonyfernandes', 0)
# ('tonyfinaugolf', 0)
# ('tonyleen', 0)
# ('tonynyssegcs', 0)
# ('toofpick', 0)
# ('toowist', 0)
# ('top100golf', 0)
# ('topgolfaustin', 0)
# ('topher2370', 0)
# ('toppscards', 0)
# ('toribowie', 0)
# ('torikelly', 0)
# ('torontodotcom', 0)
# ('torontoist', 0)
# ('torrancesam', 0)
# ('totalbetchmove', 0)
# ('totalgolfmove', 0)
# ('toulondesign', 0)
# ('tourismogourmet', 0)
# ('tourplayers', 0)
# ('tourstriker', 0)
# ('tourwifetravels', 0)
# ('traceycatherine', 0)
# ('traceyde_Leon', 0)
# ('traciglee', 0)
# ('tracy_jarrett', 0)
# ('tracybyrnes', 0)
# ('train', 0)
# ('traleegolflinks', 0)
# ('transparent_tv', 0)
# ('travarella', 0)
# ('travelgaljd', 0)
# ('traveligy', 0)
# ('travelingmoms', 0)
# ('traveljammag', 0)
# ('travelling_mom', 0)
# ('travelmail', 0)
# ('travelskills', 0)
# ('traveltuesday', 0)
# ('travelwinechick', 0)
# ('travisolsongolf', 0)
# ('trayzbrown', 0)
# ('trdmiami', 0)
# ('trentgreen10', 0)
# ('trentondaniel', 0)
# ('trevorgolfer', 0)
# ('trevorsimsby', 0)
# ('triagain', 0)
# ('triatthetrump', 120)
# ('tribeca_golf', 0)
# ('trinavargo', 0)
# ('trinity_golf', 0)
# ('triplearesale', 0)
# ('tripp_cobb', 0)
# ('trish_regan', 0)
# ('tristanwalker', 0)
# ('trixyj', 0)
# ('trob4bama', 0)
# ('tropicocunt', 0)
# ('tropicola', 0)
# ('trudeaugolf', 0)
# ('trueheartmgmt', 0)
# ('truetempergolf', 0)
# ('trulia', 0)
# ('trumpoceanclub', 0)
# ('trumpology', 0)
# ('trumptowerpde', 0)
# ('trumpwinery', 40)
# ('truth_eater', 0)
# ('truthinfantasy', 0)
# ('tsapp20', 0)
# ('tsehaia567', 0)
# ('ttswine', 0)
# ('tufayel', 0)
# ('tula_etulain', 0)
# ('tullamorepro', 0)
# ('tupcshakurswife', 0)
# ('turfPROone', 0)
# ('turf_farmer', 0)
# ('turfnet', 0)
# ('turnleftlisa', 0)
# ('turquoisepalace', 0)
# ('tvangolf', 0)
# ('tvnewser', 0)
# ('twalterpga', 0)
# ('twc14', 0)
# ('tweber', 0)
# ('tweepsmap', 0)
# ('tweetBIGB', 0)
# ('tweetlv', 0)
# ('twistedtartan', 0)
# ('twitlonger', 0)
# ('twitter', 0)
# ('twittertv', 0)
# ('twoxtherate', 0)
# ('tyhenrymedium', 0)
# ('tylerjara', 0)
# ('tyleroakley', 0)
# ('typeAtrips', 0)
# ('tyrabanks', 0)
# ('tyrusyork', 0)
# ('tysofast', 0)
# ('uabmedicine', 0)
# ('ucathletics', 0)
# ('uclamensgolf', 0)
# ('ufoparts', 0)
# ('uhnd', 0)
# ('ultimapanama', 0)
# ('ulzzang_cumi', 0)
# ('umdsfinest21', 0)
# ('under_foot', 0)
# ('undisputed', 0)
# ('unholyagb', 0)
# ('uninterrupted', 0)
# ('unionvalegolf', 0)
# ('uniquewaymexico', 0)
# ('united', 0)
# ('unitedwaySWPA', 0)
# ('unleashthekai', 0)
# ('unlvfootball', 0)
# ('upgbobcats', 0)
# ('urban_chronotis', 0)
# ('us_navyseals', 0)
# ('usabasketball', 0)
# ('usahockey', 0)
# ('usahomeofgolf', 0)
# ('usainbolt', 0)
# ('usairforce', 0)
# ('usantidoping', 0)
# ('usatf', 0)
# ('usatoday2016', 0)
# ('uscoastguard', 0)
# ('usopen', 0)
# ('usopengolf', 0)
# ('usskiteam', 0)
# ('ussoccer_wnt', 0)
# ('uttylerpatriots', 0)
# ('uwp_pioneers', 0)
# ('uxpodcast', 0)
# ('valeriehillwine', 0)
# ('valzarya', 0)
# ('vandeRede', 0)
# ('vanderkimberly', 0)
# ('vandives', 0)
# ('vanillaice', 0)
# ('vares319', 0)
# ('varianstable', 0)
# ('varoonbose', 0)
# ('vaughnFNC', 0)
# ('vawinetime', 0)
# ('vegasdistillery', 0)
# ('vegolf', 0)
# ('veramarwines', 0)
# ('verified', 0)
# ('veronicabeard', 0)
# ('vgolembewski', 0)
# ('vicenews', 0)
# ('victoiretweets', 0)
# ('victoria_clemm', 0)
# ('victoriabeckham', 0)
# ('vika7', 0)
# ('vikkimackenzie1', 0)
# ('villagevoice', 0)
# ('vincentluistri', 0)
# ('vine', 0)
# ('vinesofvirginia', 0)
# ('vineyards_com', 0)
# ('vineyardvines', 0)
# ('vino2travel', 0)
# ('vinography', 0)
# ('vinosdeamerica', 0)
# ('vinsordinaires', 0)
# ('vintagegolfer18', 0)
# ('viralvines', 0)
# ('visitabdn', 0)
# ('visitbrandywine', 0)
# ('visitennis1', 0)
# ('vivamaxweddings', 0)
# ('vivelafra', 0)
# ('vivianbutler1', 0)
# ('vividkind', 0)
# ('vivienneFrankel', 0)
# ('vkopytoff', 0)
# ('vmagazine', 0)
# ('vmas', 0)
# ('vogue_italia', 0)
# ('voguemagazine', 0)
# ('volk2845', 0)
# ('vosswater', 0)
# ('votegregwalden', 0)
# ('votermom', 0)
# ('vrichardrfm', 0)
# ('vsweetblog', 0)
# ('vu87csu90', 0)
# ('vulture', 0)
# ('vuziihomes', 0)
# ('vvirga', 0)
# ('w4djt', 0)
# ('wANNAbe2891', 0)
# ('wabashathletics', 0)
# ('wachsy1', 0)
# ('wackertime', 0)
# ('wada_ama', 0)
# ('wademyatt', 0)
# ('wagsk13wjs_e', 0)
# ('wagthedoguk', 0)
# ('waitbutwhy', 0)
# ('walkenstein', 0)
# ('walkercobrands', 0)
# ('walkingforkids', 0)
# ('walkingontravel', 0)
# ('wallyball', 0)
# ('walshjulianne', 0)
# ('wanderthevines', 0)
# ('warrenlevinson', 0)
# ('warriors', 0)
# ('warszawa', 0)
# ('washingtondc', 0)
# ('washingtonpost', 0)
# ('wassermaxe', 0)
# ('wastedwhitegirl', 0)
# ('wbpictures', 0)
# ('wbtvtraffic', 0)
# ('wcknicks', 0)
# ('wcuebas', 0)
# ('wdmartinez', 0)
# ('wdunlap', 0)
# ('wearegolf', 0)
# ('weareteamtrump', 0)
# ('weatherchannel', 0)
# ('webbsimpson1', 0)
# ('webdotcom', 0)
# ('weddingtidbits', 0)
# ('weeblacko', 0)
# ('weeetar', 0)
# ('wegmanslpga', 0)
# ('weknowwhatsbest', 0)
# ('wendyfrink', 0)
# ('wendynguyen', 0)
# ('wendystaunton', 0)
# ('wendyvoss', 0)
# ('werenskir', 0)
# ('wernerkok1', 0)
# ('wes_mensing', 0)
# ('wesleybryangolf', 0)
# ('wesleywhamond', 0)
# ('wesrap', 0)
# ('westelm', 0)
# ('westernhouseayr', 0)
# ('westminsterpa', 0)
# ('westpalmbch', 0)
# ('westwindwine', 0)
# ('wetwetwetuk', 0)
# ('wfederman', 0)
# ('wgjmag', 0)
# ('wheatiePGA', 0)
# ('whitegrlproblem', 0)
# ('whitegypsy', 0)
# ('whitney__d', 0)
# ('whitneyyoung', 0)
# ('whoffmann66', 0)
# ('wholefoodscvl', 0)
# ('whtgrlproblems', 0)
# ('wideworldofgolf', 0)
# ('widlic', 0)
# ('wigger13', 0)
# ('wigglechicken', 0)
# ('wijer0', 0)
# ('wikileaks', 0)
# ('wilbecksbbq', 0)
# ('wild4wawine', 0)
# ('will_mccants', 0)
# ('willcain', 0)
# ('willettbrad1', 0)
# ('willfthorp', 0)
# ('willhaskett', 0)
# ('willhumps16', 0)
# ('williamnoblepga', 0)
# ('williamnorwich', 0)
# ('williebosshog', 0)
# ('willows_maria', 0)
# ('willwilcoxgolf', 0)
# ('willypumarol', 0)
# ('windowskush', 0)
# ('wine_minder', 0)
# ('wineatlostcreek', 0)
# ('wineintro', 0)
# ('winespecschool', 0)
# ('wineweirdos', 0)
# ('winrosenfeld', 0)
# ('winterhighland', 0)
# ('wirereporter', 0)
# ('wisvix', 0)
# ('witathletics', 0)
# ('wizkhalifa', 0)
# ('wkyc', 0)
# ('wmag', 0)
# ('wnbachicagosky', 0)
# ('wofstargirl', 0)
# ('wolfblitzer', 0)
# ('wolfluxury', 0)
# ('wolverritchie', 0)
# ('womenofteal', 0)
# ('womensday', 0)
# ('womensfunding', 0)
# ('womensgolfcom', 0)
# ('womensgolfday', 0)
# ('wonderflmachine', 0)
# ('woodte', 0)
# ('woodyjohnson4', 0)
# ('wordofmouth4', 0)
# ('workoutathome', 0)
# ('workwthecoach', 0)
# ('worldgolf', 0)
# ('worldisourstage', 0)
# ('worldwineevents', 0)
# ('wormpowerturf', 0)
# ('worthy1961', 320)
# ('wpjenna', 0)
# ('wpkube', 0)
# ('wrightsteve19', 0)
# ('wseth54', 0)
# ('wsulancers', 0)
# ('wubearcats', 0)
# ('wudeydo34', 0)
# ('wunderground', 0)
# ('wuppleswine', 0)
# ('wwd', 0)
# ('xOfficialLauren', 0)
# ('xXSulliXx30', 0)
# ('xalumnidirector', 0)
# ('xandermac_', 0)
# ('xenaproductions', 0)
# ('xlysandrax', 0)
# ('xmcj', 0)
# ('xnaomicookex', 0)
# ('xoMoniqueox', 0)
# ('xoPrincessStina', 0)
# ('xoxotaliab', 0)
# ('xtina', 0)
# ('yadiramartinez', 0)
# ('yanawhatimean', 0)
# ('yehudaberg', 0)
# ('yelenaleu', 0)
# ('yelenanersesyan', 0)
# ('yoabbaabba', 0)
# ('yokoono', 0)
# ('yoshioyz', 0)
# ('yourgolftravel', 0)
# ('yoursundaybag', 0)
# ('yulypinzon07', 0)
# ('yunggriffsays', 0)
# ('z_blair', 0)
# ('zack_hample', 0)
# ('zaibatsu', 0)
# ('zbig', 0)
# ('zbrady7940', 0)
# ('zdecicco', 0)
# ('zekejwilliams', 0)
# ('zeldawilliams', 0)
# ('zellieimani', 0)
# ('zenfreeman', 0)
# ('zerohedge', 0)
# ('zeropercent', 0)
# ('zgriff64', 0)
# ('zillow', 0)
# ('zoehajjam', 0)
# ('zstumgoren', 0)
# ('zuccarello36', 0)
# ('zzzzaaaacccchhh', 0)
# 12403

# %% [markdown]
# ## Q2. Visualization [2pts + 7pts + 4pts]
# In this question, you will load all data into pandas dataframes and analyse (and visualize!) some interesting trends using [matplotlib](http://matplotlib.org) python package.

# %% [markdown]
# ### Q2. Task A: Load Twitter data using pandas [2pts]
# Fill in the following method stub and return the data frames for users, edges and tweets.
#
# Pandas will treat missing values as NaNs by default. However, for this assignment, you should treat missing values (i.e., empty strings in the csv files) as empty strings.

# %%
def load_twitter_data_pandas(users_filepath, edges_filepath, tweets_filepath):
    """ Loads the Twitter data from the csv files into Pandas dataframes
    Input:
        users_filepath (str) : absolute/relative path to users.csv file
        edges_filepath (str) : absolute/relative path to edges.csv file
        tweets_filepath (str) : absolute/relative path to tweets.csv file
    Output:
        (pd.DataFrame, pd.DataFrame, pd.DataFrame) : A tuple of three dataframes, the first one for users,
                                                    the second for edges and the third for tweets.
    """
    users = pd.read_csv(users_filepath);
    users = users.fillna("")
    edges = pd.read_csv(edges_filepath);
    edges = edges.fillna("")
    tweets = pd.read_csv(tweets_filepath);
    tweets = tweets.fillna("")
    
    return (users,edges,tweets)

# %% [markdown]
# You can test your function using the following code.

# %%
# AUTOLAB_IGNORE_START
(users_df, edges_df, tweets_df) = load_twitter_data_pandas('users.csv', 'edges.csv', 'tweets.csv')
# make sure to change the path to csv files appropriately
print users_df.head()
print edges_df.head()
print tweets_df.head()
# AUTOLAB_IGNORE_STOP
# Out:
#                  name      screen_name      location  \
# 0     Donald J. Trump  realDonaldTrump  New York, NY
# 1  Trump Organization            Trump  New York, NY
# 2          Trump Golf        TrumpGolf
# 3       Tiffany Trump    TiffanyATrump
# 4      Laura Ingraham    IngrahamAngle            DC
#
#                        created_at  friends_count  followers_count  \
# 0  Wed Mar 18 13:46:38 +0000 2009             42         11397769
# 1  Wed Apr 13 16:51:54 +0000 2016             35             9954
# 2  Mon Feb 03 13:46:03 +0000 2014            200             8797
# 3  Tue Feb 01 20:59:30 +0000 2011             79            63138
# 4  Thu Jun 25 21:03:25 +0000 2009            289           851876
#
#    statuses_count  favourites_count
# 0           33136                38
# 1              43               125
# 2             758               251
# 3             573                28
# 4           26523                71
#        screen_name         friend
# 0  realDonaldTrump          Trump
# 1  realDonaldTrump      TrumpGolf
# 2  realDonaldTrump  TiffanyATrump
# 3  realDonaldTrump  IngrahamAngle
# 4  realDonaldTrump     mike_pence
#        screen_name                      created_at  retweet_count  \
# 0  realDonaldTrump  Fri Sep 09 02:00:32 +0000 2016           2859
# 1  realDonaldTrump  Fri Sep 09 00:39:36 +0000 2016           6463
# 2  realDonaldTrump  Thu Sep 08 23:56:22 +0000 2016           5405
# 3  realDonaldTrump  Thu Sep 08 19:52:32 +0000 2016          11633
# 4  realDonaldTrump  Thu Sep 08 18:17:01 +0000 2016           3824
#
#    favorite_count                                               text
# 0            7030  Final poll results from NBC on last nights Com...
# 1           17951  It wasn't Matt Lauer that hurt Hillary last ni...
# 2           13223  More poll results from last nights Commander-i...
# 3           27028  Last nights results - in poll taken by NBC. #A...
# 4           12567  With Luis, Mexico and the United States would ...

# %% [markdown]
# ### Q2. Task B: Correlation [4pts + 3pts]
# Statisticians and data analysts usually like to study about correlation between different observed variables. This helps uncover interesting patterns in the data such as causal relationships (e.g., snow on the road leads to increase in number of accidents). Correlation studies are important for multiple reasons:
# - While [correlation does not imply causation](https://en.wikipedia.org/wiki/Correlation_does_not_imply_causation), a lack of correlation implies a lack of causation. This can be used to rule out many causal relationships.
# - Correlation helps with prediction. The more closely related two variables are, the easier it is to predict one from the other.
#
# In this task, we ask you to plot the friends_count (on y-axis) vs the followers_count (on x-axis) using the matplotlib package. [Here](http://matplotlib.org/examples/shapes_and_collections/scatter_demo.html) is an example to get started with scatter plots.

# %%
def plot_friends_vs_followers(users_df):
    """ Plots the friends_count (on y-axis) against the followers_count (on x-axis).
    Input:
        users_df (pd.DataFrame) : Dataframe containing Twitter user attributes,
                                    as returned by load_twitter_data_pandas()
    Output:
        (matplotlib.collections.PathCollection) : The object returned by the scatter plot function
    """
    return plt.scatter(users_df.loc[:,"followers_count"],users_df.loc[:,"friends_count"])

# AUTOLAB_IGNORE_START
p = plot_friends_vs_followers(users_df)
plt.show()
# AUTOLAB_IGNORE_STOP

# %% [markdown]
# Do you see a correlation between these two variables from your scatter plot? Let's measure this quantitatively using the [Pearson's correlation coefficient](https://en.wikipedia.org/wiki/Pearson_product-moment_correlation_coefficient).
#
# For a set of observations $(X,Y) = [(x_1,y_1), (x_2,y_2), ... , (x_n,y_n)]$, the Pearson's correlation coefficient is a measure of the linear dependence between two variables $X$ and $Y$, giving a value between +1 and −1 inclusive, where 1 is total positive correlation, 0 is no correlation, and −1 is total negative correlation.
#
# $r=r_{xy}={\frac {n\sum x_{i}y_{i}-\sum x_{i}\sum y_{i}}{{\sqrt {n\sum x_{i}^{2}-(\sum x_{i})^{2}}}~{\sqrt {n\sum y_{i}^{2}-(\sum y_{i})^{2}}}}}$
#
# Now, fill in the following function to compute the Pearson's correlation coefficient between friends_count and followers_count.

# %%
def correlation_coefficient(users_df):
    """ Plots the friends_count (on y-axis) against the followers_count (on x-axis).
    Input:
        users_df (pd.DataFrame) : Dataframe containing Twitter user attributes,
                                    as returned by load_twitter_data_pandas()
    Output:
        (double) : correlation coefficient between friends_count and followers_count
    """
    # X = FOLLOWERS Y = FRIENDS_COUNT
    sum_xy = 0.00
    sum_x = 0.00
    sum_y = 0.00
    sum_x_squared = 0.00
    sum_y_squared = 0.00
    corr = 0.00 
    
    num_records = len(users_df)
    followers_count = users_df.loc[:,"followers_count"]
    friends_count = users_df.loc[:,"friends_count"]
    for i in xrange(num_records):
        x = followers_count[i]
        y = friends_count[i]        
        sum_xy += x*y
        sum_x += x
        sum_y += y
        sum_x_squared += x*x
        sum_y_squared += y*y
        
    num = (num_records*sum_xy) - (sum_x*sum_y)
    den = math.sqrt(num_records*sum_x_squared - (sum_x*sum_x))*math.sqrt(num_records*sum_y_squared - (sum_y*sum_y))
    corr = num/den;
    return corr

# AUTOLAB_IGNORE_START
print correlation_coefficient(users_df)
# AUTOLAB_IGNORE_STOP
# Out:
# 0.0930864051648

# %% [markdown]
# ### Q2. Task C: Degree distribution [4pts]
# If you are not familiar with graph theory and/or graph mining, skip the first paragraph.
#
# As you're familiar with graphs, you might know that the degree of a node is the number of connections it has to other nodes. A common statistic to look out for in the case of real world graphs is the degree distribution. Literature says degrees of nodes in real world graphs follow a [power law distribution](https://en.wikipedia.org/wiki/Power_law). The implication is that a scatter plot of num_users versus k (as we will define below) yields an almost straight line. In this task, we shall verify whether the given crawl of Twitter network satisfies this property.
#
# Let us call the number of friends a Twitter user has as his/her degree. The degree distribution is a histogram of the number of friends. Your task is to visualize this histogram. Use the default number of bins.

# %%
def degree_distribution(edges_df):
    """ Plots the distribution of .
    Input:
        edges_df (pd.DataFrame) : Dataframe containing Twitter edges,
                        as returned by load_twitter_data_pandas()
    Output:
        (array, array, list of Patch objects) : Tuple of the values of the histogram bins, 
                        the edges of the bins and the silent list of individual patches used to create the histogram.
    """
    num_rec = len(edges_df);
    count = edges_df.groupby("screen_name").size()
    n, bins, patches = plt.hist(count)
    return (n,bins,patches);
    
    
    

# AUTOLAB_IGNORE_START
degree_distribution(edges_df)
# AUTOLAB_IGNORE_STOP
# Out:
# (array([   2.,    6.,    2.,    5.,    4.,    4.,    3.,    1.,    4.,  148.]),
#  array([   2. ,   11.8,   21.6,   31.4,   41.2,   51. ,   60.8,   70.6,
#           80.4,   90.2,  100. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Do you notice any surprising/unexpected pattern? What can you say about the way in which the Twitter data was collected?
